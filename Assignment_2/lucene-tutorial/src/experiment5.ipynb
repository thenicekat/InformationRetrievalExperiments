# %%
import indexer
import csv
from collections import defaultdict
from tqdm import tqdm
import pandas as pd
import pickle
import re

# %% [markdown]
# ### Creating the indexes

# %%
index = {}

print("Registering entities")
with open('../../gena_data_final_triples.csv', 'r') as file:
    reader = csv.reader(file)
    next(reader)
    for row in tqdm(reader, total=1026316):
        for entity in row:
            if entity not in index:
                index[entity] = defaultdict(int)

with open('index_only_entities.pkl', 'wb') as file:
    pickle.dump(index, file)

index
# Out:
# Registering entities
# 100%|█████████▉| 1026307/1026316 [00:02<00:00, 428743.68it/s]
# {'Flibanserin': defaultdict(int, {}),
#  'Type_E1': defaultdict(int, {}),
#  'CHEMICAL': defaultdict(int, {}),
#  'Sentence': defaultdict(int, {}),
#  'Flibanserin, a multifunctional serotonin receptor agonist and antagonist, is currently approved in the United States and Canada for the treatment of acquired, generalized hypoactive sexual desire disorder (HSDD) in premenopausal women.': defaultdict(int,
#              {}),
#  'ID_1': defaultdict(int, {}),
#  'C098107': defaultdict(int, {}),
#  'Full_E1': defaultdict(int, {}),
#  'MeSH_E1': defaultdict(int, {}),
#  'flibanserin [Supplementary Concept]': defaultdict(int, {}),
#  'Synonyms_1': defaultdict(int, {}),
#  'Benzimidazoles': defaultdict(int, {}),
#  'multifunctional serotonin receptor agonist': defaultdict(int, {}),
#  'NEW00001': defaultdict(int, {}),
#  'No synonyms': defaultdict(int, {}),
#  'Obesity': defaultdict(int, {}),
#  'DISEASE': defaultdict(int, {}),
#  'Obesity is associated with reduced testosterone and worsened erectile and sexual function in men.': defaultdict(int,
#              {}),
#  'D063766': defaultdict(int, {}),
#  'Pediatric Obesity': defaultdict(int, {}),
#  'Obesity, Pediatric': defaultdict(int, {}),
#  'Obesity in Childhood': defaultdict(int, {}),
#  'Childhood Onset Obesity': defaultdict(int, {}),
#  'Obesity, Childhood Onset': defaultdict(int, {}),
#  'Child Obesity': defaultdict(int, {}),
#  'Obesity, Child': defaultdict(int, {}),
#  'Childhood Obesity': defaultdict(int, {}),
#  'Obesity, Childhood': defaultdict(int, {}),
#  'Adolescent Obesity': defaultdict(int, {}),
#  'Obesity, Adolescent': defaultdict(int, {}),
#  'Obesity in Adolescence': defaultdict(int, {}),
#  'Infantile Obesity': defaultdict(int, {}),
#  'Obesity, Infantile': defaultdict(int, {}),
#  'Infant Obesity': defaultdict(int, {}),
#  'Obesity, Infant': defaultdict(int, {}),
#  'Childhood Overweight': defaultdict(int, {}),
#  'Overweight, Childhood': defaultdict(int, {}),
#  'Infant Overweight': defaultdict(int, {}),
#  'Overweight, Infant': defaultdict(int, {}),
#  'Adolescent Overweight': defaultdict(int, {}),
#  'Overweight, Adolescent': defaultdict(int, {}),
#  'montelukast': defaultdict(int, {}),
#  'Although montelukast is considered to be a safe drug, there are concerns regarding adverse drug reactions, including the rare occurrence of Churg-Strauss syndrome and, despite insufficient data, the possibility of neuropsychiatric events such as anxiety, depression, sleep disturbance, and suicidality.': defaultdict(int,
#              {}),
#  'C093875': defaultdict(int, {}),
#  'montelukast [Supplementary Concept]': defaultdict(int, {}),
#  'Acetates': defaultdict(int, {}),
#  'Cyclopropanes': defaultdict(int, {}),
#  'Quinolines': defaultdict(int, {}),
#  'Sulfides': defaultdict(int, {}),
#  'omega-3 fatty acids': defaultdict(int, {}),
#  'NUTRITION': defaultdict(int, {}),
#  'Since omega-3 fatty acids like EPA are precursors for the biosynthesis of eicosanoids including leukotrienes, a common factor to these psychiatric adverse events may be perturbations in this highly complex system of lipid inflammatory mediators.': defaultdict(int,
#              {}),
#  'D015525': defaultdict(int, {}),
#  'Fatty Acids, Omega-3': defaultdict(int, {}),
#  'Omega-3 Fatty Acid': defaultdict(int, {}),
#  'Acid, Omega-3 Fatty': defaultdict(int, {}),
#  'Fatty Acid, Omega-3': defaultdict(int, {}),
#  'Omega 3 Fatty Acid': defaultdict(int, {}),
#  'Omega-3 Fatty Acids': defaultdict(int, {}),
#  'n-3 Oil': defaultdict(int, {}),
#  'Oil, n-3': defaultdict(int, {}),
#  'n 3 Oil': defaultdict(int, {}),
#  'n3 Oil': defaultdict(int, {}),
#  'Oil, n3': defaultdict(int, {}),
#  'n-3 Fatty Acids': defaultdict(int, {}),
#  'n 3 Fatty Acids': defaultdict(int, {}),
#  'Omega 3 Fatty Acids': defaultdict(int, {}),
#  'n-3 PUFA': defaultdict(int, {}),
#  'PUFA, n-3': defaultdict(int, {}),
#  'n 3 PUFA': defaultdict(int, {}),
#  'n3 Fatty Acid': defaultdict(int, {}),
#  'Fatty Acid, n3': defaultdict(int, {}),
#  'n3 PUFA': defaultdict(int, {}),
#  'PUFA, n3': defaultdict(int, {}),
#  'n3 Polyunsaturated Fatty Acid': defaultdict(int, {}),
#  'n3 Oils': defaultdict(int, {}),
#  'n-3 Oils': defaultdict(int, {}),
#  'n 3 Oils': defaultdict(int, {}),
#  'N-3 Fatty Acid': defaultdict(int, {}),
#  'Acid, N-3 Fatty': defaultdict(int, {}),
#  'Fatty Acid, N-3': defaultdict(int, {}),
#  'N 3 Fatty Acid': defaultdict(int, {}),
#  'n-3 Polyunsaturated Fatty Acid': defaultdict(int, {}),
#  'n 3 Polyunsaturated Fatty Acid': defaultdict(int, {}),
#  'EPA': defaultdict(int, {}),
#  'D015118': defaultdict(int, {}),
#  'eicosapentaenoic acid': defaultdict(int, {}),
#  'Eicosapentaenoic Acid': defaultdict(int, {}),
#  '5,8,11,14,17-Eicosapentaenoic Acid': defaultdict(int, {}),
#  'Eicosapentanoic Acid': defaultdict(int, {}),
#  'Acid, Eicosapentanoic': defaultdict(int, {}),
#  'omega-3-Eicosapentaenoic Acid': defaultdict(int, {}),
#  'omega 3 Eicosapentaenoic Acid': defaultdict(int, {}),
#  'Timnodonic Acid': defaultdict(int, {}),
#  'Icosapent': defaultdict(int, {}),
#  '5,8,11,14,17-Icosapentaenoic Acid': defaultdict(int, {}),
#  'Results Previous use of montelukast correlated with improved scores on cognitive or neurological functioning (F\u2009=\u20092.20, p\u2009=\u20090.03 in a multivariate test).': defaultdict(int,
#              {}),
#  'Ascorbic acid': defaultdict(int, {}),
#  'BIOCHEMICAL': defaultdict(int, {}),
#  "Ascorbic acid has emerged as a neuroprotective compound against neurotoxicants and neurodegenerative diseases, including Alzheimer's disease, multiple sclerosis and amyotrophic lateral sclerosis.": defaultdict(int,
#              {}),
#  'D001206': defaultdict(int, {}),
#  'Ascorbic Acid Deficiency': defaultdict(int, {}),
#  'Vitamin C Deficiency': defaultdict(int, {}),
#  'Deficiency, Vitamin C': defaultdict(int, {}),
#  'Deficiencies, Vitamin C': defaultdict(int, {}),
#  'Vitamin C Deficiencies': defaultdict(int, {}),
#  'Deficiency, Ascorbic Acid': defaultdict(int, {}),
#  'Ascorbic Acid Deficiencies': defaultdict(int, {}),
#  'Deficiencies, Ascorbic Acid': defaultdict(int, {}),
#  'schizophrenic patients': defaultdict(int, {}),
#  'We previously reported that a certain subtype of schizophrenic patients exhibit idiopathic carbonyl stress with high plasma pentosidine levels and the depletion of vitamin B6, without underlying diabetes or chronic kidney disease, the two major causes of elevated AGEs.': defaultdict(int,
#              {}),
#  'NEW00007': defaultdict(int, {}),
#  'In particular, the markedly lowered vitamin B6 levels in schizophrenic patients with high pentosidine levels suggest that pyridoxamine may prove to be clinically useful.': defaultdict(int,
#              {}),
#  'lowered vitamin B6 levels': defaultdict(int, {}),
#  'NEW00011': defaultdict(int, {}),
#  'hemorrhagic disease': defaultdict(int, {}),
#  'Intramuscular administration of vitamin K for prophylaxis against hemorrhagic disease of the newborn has the disadvantage of increased cost, pain, anxiety to parents and risk of transmission of infection.': defaultdict(int,
#              {}),
#  'D018164': defaultdict(int, {}),
#  'Hemorrhagic Disease Virus, Epizootic': defaultdict(int, {}),
#  'Epizootic hemorrhagic disease virus': defaultdict(int, {}),
#  'vitamin K': defaultdict(int, {}),
#  'D064417': defaultdict(int, {}),
#  'Vitamin K Epoxide Reductases': defaultdict(int, {}),
#  'Vitamin K Epoxidase': defaultdict(int, {}),
#  'Epoxidase, Vitamin K': defaultdict(int, {}),
#  'K Epoxidase, Vitamin': defaultdict(int, {}),
#  'Phylloquinone Epoxide Reductase': defaultdict(int, {}),
#  'Epoxide Reductase, Phylloquinone': defaultdict(int, {}),
#  'Reductase, Phylloquinone Epoxide': defaultdict(int, {}),
#  'Vitamin KO Reductase': defaultdict(int, {}),
#  'Reductase, Vitamin KO': defaultdict(int, {}),
#  'Vitamin K 2,3-Epoxide Reductase': defaultdict(int, {}),
#  'Vitamin K 2,3 Epoxide Reductase': defaultdict(int, {}),
#  'Vitamin K Epoxide Reductase': defaultdict(int, {}),
#  'Vitamin K1 Oxide Reductase': defaultdict(int, {}),
#  'Menadione Epoxide Reductase': defaultdict(int, {}),
#  'Epoxide Reductase, Menadione': defaultdict(int, {}),
#  'Reductase, Menadione Epoxide': defaultdict(int, {}),
#  'Vitamin K 1 Epoxidase': defaultdict(int, {}),
#  'Riboflavin transporter deficiency': defaultdict(int, {}),
#  'Riboflavin transporter deficiency 2 (RTD2) is a rare neurological disorder caused by mutations in the Solute carrier family 52 member 2 (Slc52a2) gene encoding human riboflavin transporter 2 (RFVT2).': defaultdict(int,
#              {}),
#  'NEW00013': defaultdict(int, {}),
#  'folate deficiency': defaultdict(int, {}),
#  'Several studies demonstrate a clinical correlation between folate deficiency and psychiatric hospitalization.': defaultdict(int,
#              {}),
#  'NEW00014': defaultdict(int, {}),
#  'psychiatric hospitalization': defaultdict(int, {}),
#  'NEW00015': defaultdict(int, {}),
#  'psychiatric patients': defaultdict(int, {}),
#  'These observations agree that psychiatric patients are more likely to have low serum folate values, and suggest that poor diet does not explain the increased likelihood.': defaultdict(int,
#              {}),
#  'NEW00016': defaultdict(int, {}),
#  'B12 insufficiency': defaultdict(int, {}),
#  'Although our study does not show that B12 insufficiency is a direct risk factor to cognitive decline, B12 levels could be a contributing factor to cognitive function.': defaultdict(int,
#              {}),
#  'NEW00018': defaultdict(int, {}),
#  'Biotin-dependent carboxylases': defaultdict(int, {}),
#  'Biotin-dependent carboxylases catalyze the fixation of bicarbonate in organic acids and play crucial roles in the metabolism of fatty acids, amino acids and glucose.': defaultdict(int,
#              {}),
#  'NEW00019': defaultdict(int, {}),
#  'biotin deficiency': defaultdict(int, {}),
#  'Symptoms of biotin deficiency include seizures, hypotonia, ataxia, dermatitis, hair loss, mental retardation, ketolactic acidosis, organic aciduria and also fetal malformations.': defaultdict(int,
#              {}),
#  'C531633': defaultdict(int, {}),
#  'Biotin deficiency [Supplementary Concept]': defaultdict(int, {}),
#  'Biotinidase Deficiency': defaultdict(int, {}),
#  'folate levels': defaultdict(int, {}),
#  'Meta-analyses showed significantly lower vitamin B12 levels in ASD and ADHD patients vs. healthy controls (HC), while folate levels were higher in ADHD patients vs. HC.': defaultdict(int,
#              {}),
#  'NEW00022': defaultdict(int, {}),
#  'vitamin abnormalities': defaultdict(int, {}),
#  'There was significant heterogeneity between the studies, however many found different types of vitamin abnormalities in CAD with psychiatric disorders.': defaultdict(int,
#              {}),
#  'NEW00024': defaultdict(int, {}),
#  'AD VaD patients': defaultdict(int, {}),
#  'AD and VaD patients showed similar plasma levels of plasma antioxidants and MDA as well as a similar IgG content of protein carbonyls and dityrosine.': defaultdict(int,
#              {}),
#  'NEW00025': defaultdict(int, {}),
#  'serotonin 5-HT1A/1B receptor agonist eltoprazine': defaultdict(int, {}),
#  "The serotonin 5-HT1A/1B receptor agonist eltoprazine suppressed dyskinetic-like behavior in animal models of Parkinson's disease (PD) but simultaneously reduced levodopa (l-dopa)-induced motility.": defaultdict(int,
#              {}),
#  'NEW00026': defaultdict(int, {}),
#  'adenosine A2A receptor antagonists': defaultdict(int, {}),
#  'Moreover, adenosine A2A receptor antagonists, such as preladenant, significantly increased l-dopa efficacy in PD without exacerbating dyskinetic-like behavior.': defaultdict(int,
#              {}),
#  'D058917': defaultdict(int, {}),
#  'Adenosine A2 Receptor Antagonists': defaultdict(int, {}),
#  'Adenosine A2B Receptor Antagonists': defaultdict(int, {}),
#  'Adenosine A2A Receptor Antagonists': defaultdict(int, {}),
#  'preladenant': defaultdict(int, {}),
#  'C539997': defaultdict(int, {}),
#  '2-(2-furanyl)-7-(2-(4-(4-(2-methoxyethoxy)phenyl)-1-piperazinyl)ethyl)-7H-pyrazolo(4,3-e)(1,2,4)triazolo(1,5-c)pyrimidine-5-amine [Supplementary Concept]': defaultdict(int,
#              {}),
#  'Pyrimidines': defaultdict(int, {}),
#  'Triazoles': defaultdict(int, {}),
#  'CSC': defaultdict(int, {}),
#  'Acute administration of the adenosine A2A receptor antagonists CSC or MSX-3 at the highest doses tested (5 and 1.25mg/kg, respectively) significantly reduces haloperidol-induced catalepsy.': defaultdict(int,
#              {}),
#  'NEW00030': defaultdict(int, {}),
#  'chronic subordinate colony housing': defaultdict(int, {}),
#  'ACPT-I': defaultdict(int, {}),
#  'Furthermore, the acute co-administration of ACPT-I 1mg/kg, but not 5mg/kg, with CSC markedly reduces catalepsy.': defaultdict(int,
#              {}),
#  'C108242': defaultdict(int, {}),
#  '1-aminocyclopentane-1,3,4-tricarboxylic acid [Supplementary Concept]': defaultdict(int,
#              {}),
#  'Cyclopentanes': defaultdict(int, {}),
#  'Tricarboxylic Acids': defaultdict(int, {}),
#  'MPEP': defaultdict(int, {}),
#  'After a 3-week treatment, however, the combination of CSC and MPEP was found to reduce haloperidol-induced catalepsy.': defaultdict(int,
#              {}),
#  'NEW00032': defaultdict(int, {}),
#  'mGluR5 inverse agonist 2-methyl-6-(phenylethynyl)pyridine': defaultdict(int,
#              {}),
#  'Altogether, these results show for the first time that systemic activation of group III mGlu receptors with ACPT-I provides benefits in parkinsonian rats and underlie a possible interaction with A2A receptors to regulate basal ganglia motor function.': defaultdict(int,
#              {}),
#  'L-3,4-dihydroxyphenylalanine': defaultdict(int, {}),
#  "Long-term therapy with L-3,4-dihydroxyphenylalanine (L-DOPA), still the most effective treatment in Parkinson's disease (PD), is associated with severe motor complications such as dyskinesia.": defaultdict(int,
#              {}),
#  'D007980': defaultdict(int, {}),
#  'Levodopa': defaultdict(int, {}),
#  'L-Dopa': defaultdict(int, {}),
#  'L Dopa': defaultdict(int, {}),
#  '3-Hydroxy-L-tyrosine': defaultdict(int, {}),
#  '3 Hydroxy L tyrosine': defaultdict(int, {}),
#  'L-3,4-Dihydroxyphenylalanine': defaultdict(int, {}),
#  'L 3,4 Dihydroxyphenylalanine': defaultdict(int, {}),
#  'Levopa': defaultdict(int, {}),
#  'Larodopa': defaultdict(int, {}),
#  'Dopaflex': defaultdict(int, {}),
#  'Dopar': defaultdict(int, {}),
#  "Parkinson's disease": defaultdict(int, {}),
#  'D010300': defaultdict(int, {}),
#  'Parkinson Disease': defaultdict(int, {}),
#  "Idiopathic Parkinson's Disease": defaultdict(int, {}),
#  "Lewy Body Parkinson's Disease": defaultdict(int, {}),
#  "Parkinson's Disease, Idiopathic": defaultdict(int, {}),
#  "Parkinson's Disease, Lewy Body": defaultdict(int, {}),
#  'Parkinson Disease, Idiopathic': defaultdict(int, {}),
#  "Parkinson's Disease": defaultdict(int, {}),
#  'Idiopathic Parkinson Disease': defaultdict(int, {}),
#  'Lewy Body Parkinson Disease': defaultdict(int, {}),
#  'Primary Parkinsonism': defaultdict(int, {}),
#  'Parkinsonism, Primary': defaultdict(int, {}),
#  'Paralysis Agitans': defaultdict(int, {}),
#  'L-DOPA': defaultdict(int, {}),
#  'NEW00034': defaultdict(int, {}),
#  'dopamine precursor L-3,4-dihydroxyphenylalanine': defaultdict(int, {}),
#  'KW-6002': defaultdict(int, {}),
#  'Istradefylline (KW-6002) is the first of several adenosine A2A receptor antagonists in development for PD to advance to phase III clinical trials.': defaultdict(int,
#              {}),
#  'C111599': defaultdict(int, {}),
#  'Istradefylline': defaultdict(int, {}),
#  'istradefylline [Supplementary Concept]': defaultdict(int, {}),
#  'Purines': defaultdict(int, {}),
#  'caffeine': defaultdict(int, {}),
#  'Lastly, epidemiological evidence indicates that regular human consumption of caffeine, the most widely used psychoactive drug and nonselective AR antagonists, is associated with the reduced cognitive decline in aging and AD patients, and with the reduced risk in developing PD.': defaultdict(int,
#              {}),
#  'D002110': defaultdict(int, {}),
#  'Caffeine': defaultdict(int, {}),
#  '1,3,7-Trimethylxanthine': defaultdict(int, {}),
#  'Vivarin': defaultdict(int, {}),
#  'Caffedrine': defaultdict(int, {}),
#  'Coffeinum N': defaultdict(int, {}),
#  'Percutaféine': defaultdict(int, {}),
#  'Dexitac': defaultdict(int, {}),
#  'Durvitan': defaultdict(int, {}),
#  'No Doz': defaultdict(int, {}),
#  'Percoffedrinol N': defaultdict(int, {}),
#  'Quick-Pep': defaultdict(int, {}),
#  'Quick Pep': defaultdict(int, {}),
#  'QuickPep': defaultdict(int, {}),
#  'Coffeinum Purrum': defaultdict(int, {}),
#  'psychoactive drug': defaultdict(int, {}),
#  'D011619': defaultdict(int, {}),
#  'Psychotropic Drugs': defaultdict(int, {}),
#  'Drugs, Psychotropic': defaultdict(int, {}),
#  'Psychoactive Agent': defaultdict(int, {}),
#  'Agent, Psychoactive': defaultdict(int, {}),
#  'Psychoactive Drug': defaultdict(int, {}),
#  'Drug, Psychoactive': defaultdict(int, {}),
#  'Psychopharmaceuticals': defaultdict(int, {}),
#  'Psychoactive Agents': defaultdict(int, {}),
#  'Agents, Psychoactive': defaultdict(int, {}),
#  'Psychoactive Drugs': defaultdict(int, {}),
#  'Drugs, Psychoactive': defaultdict(int, {}),
#  'Psychotropic Drug': defaultdict(int, {}),
#  'Drug, Psychotropic': defaultdict(int, {}),
#  'Psychopharmaceutical': defaultdict(int, {}),
#  'Adenosine A2A receptor antagonists': defaultdict(int, {}),
#  "Adenosine A2A receptor antagonists represent a new way forward in the symptomatic treatment of Parkinson's disease (PD) through a non-dopaminergic mechanism.": defaultdict(int,
#              {}),
#  'adenosine A2A antagonists': defaultdict(int, {}),
#  'As a class, adenosine A2A antagonists are effective in reversing motor deficits in haloperidol-treated rodents, 6-OHDA-lesioned rats, and MPTP-treated primates when combined with low doses of l-dopa or dopamine agonist drugs.': defaultdict(int,
#              {}),
#  'NEW00035': defaultdict(int, {}),
#  'Adenosine A2A receptor antagonists are active in animal models of reduced cognition, anxiety, and depression and so this drug class may also be effective in controlling the neuropsychiatric components of nonmotor symptoms in PD.': defaultdict(int,
#              {}),
#  'A2A antagonists': defaultdict(int, {}),
#  'Preclinical evidence has shown that A2A antagonists can prevent neuronal loss in experimental models of PD and their disease modifying activity needs to be explored in man.': defaultdict(int,
#              {}),
#  'NEW00039': defaultdict(int, {}),
#  'rimonabant': defaultdict(int, {}),
#  'These results suggest that rimonabant can prevent the relapse to alcohol, even when an interaction with nicotine exists-the most frequent situation in human alcohol abuse.': defaultdict(int,
#              {}),
#  'D000077285': defaultdict(int, {}),
#  'Rimonabant': defaultdict(int, {}),
#  'SR141716': defaultdict(int, {}),
#  'SR 141716': defaultdict(int, {}),
#  'Rimonabant Hydrochloride': defaultdict(int, {}),
#  'N-(Piperidin-1-yl)-5-(4-chlorophenyl)-1-(2,4-dichlorophenyl)-4-methyl-1H-pyrazole-3-carboxamide hydrochloride': defaultdict(int,
#              {}),
#  'Zimulti': defaultdict(int, {}),
#  'SR 141716A': defaultdict(int, {}),
#  'SR-141716A': defaultdict(int, {}),
#  'SR141716A': defaultdict(int, {}),
#  'Acomplia': defaultdict(int, {}),
#  'acid/kainate receptor-type neurotoxicity': defaultdict(int, {}),
#  'N-methyl-D-aspartate receptor-induced toxicity has been shown to be calcium dependent; this study demonstrates that 2-amino-3-(4-butyl-3-hydroxyisoxazol-5-yl)propionic acid/kainate receptor-type neurotoxicity is also calcium-dependent, partly mediated by voltage sensitive calcium channels.': defaultdict(int,
#              {}),
#  'NEW00041': defaultdict(int, {}),
#  'oxotremorine treatment': defaultdict(int, {}),
#  'In this study, we have evaluated the effect of oxotremorine treatment on chronic restraint stress-induced cognitive deficits.': defaultdict(int,
#              {}),
#  'NEW00043': defaultdict(int, {}),
#  'tramadol administration': defaultdict(int, {}),
#  'Overall, the outcomes of this study suggest that tramadol administration has a neurodegeneration effect on the cerebellar cortex via several pathways consisting of microgliosis, apoptosis, necroptosis, and neuroinflammatoin.': defaultdict(int,
#              {}),
#  'NEW00045': defaultdict(int, {}),
#  'clozapine': defaultdict(int, {}),
#  'Concerns about intentional and unintentional poisoning present a barrier to wider use of clozapine in treatment-resistant schizophrenia.': defaultdict(int,
#              {}),
#  'D003024': defaultdict(int, {}),
#  'Clozapine': defaultdict(int, {}),
#  'Clozaril': defaultdict(int, {}),
#  'Leponex': defaultdict(int, {}),
#  'AOP': defaultdict(int, {}),
#  'AOP correlated in CNCP OST patients with: age ≤ 40 years old, female gender, low-income status, methadone-maintained treatment, mental health disorder, hepatitis C virus (HCV) infection, and alcohol abuse disorder.': defaultdict(int,
#              {}),
#  'NEW00047': defaultdict(int, {}),
#  'analgesic opioid prescription': defaultdict(int, {}),
#  'nefopam': defaultdict(int, {}),
#  'A 5 mg/kg dose of nefopam significantly elevated the electric seizure threshold, while a dose of 1 mg/kg failed to protect mice against electroconvulsion.': defaultdict(int,
#              {}),
#  'D009340': defaultdict(int, {}),
#  'Nefopam': defaultdict(int, {}),
#  'Nefopam Hydrochloride': defaultdict(int, {}),
#  'Hydrochloride, Nefopam': defaultdict(int, {}),
#  'Fenazoxine': defaultdict(int, {}),
#  'Acupan': defaultdict(int, {}),
#  'Ajan': defaultdict(int, {}),
#  'Silentan Nefopam': defaultdict(int, {}),
#  'Nefopam, Silentan': defaultdict(int, {}),
#  'Oxycodone': defaultdict(int, {}),
#  'Oxycodone is administered to opioid-naive patients with severe pain and to patients who were unsuccessfully treated with weak opioids, namely tramadol, codeine and dihydrocodeine.': defaultdict(int,
#              {}),
#  'D010098': defaultdict(int, {}),
#  'Dihydrone': defaultdict(int, {}),
#  'Oxycone': defaultdict(int, {}),
#  'Dihydrohydroxycodeinone': defaultdict(int, {}),
#  'Oxycodeinon': defaultdict(int, {}),
#  'Eucodal': defaultdict(int, {}),
#  'Theocodin': defaultdict(int, {}),
#  'Oxycodone Hydrochloride': defaultdict(int, {}),
#  'Oxycontin': defaultdict(int, {}),
#  'Pancodine': defaultdict(int, {}),
#  'Dinarkon': defaultdict(int, {}),
#  'Oxiconum': defaultdict(int, {}),
#  'morphine': defaultdict(int, {}),
#  'Oxycodone displays high bioavailability after oral administration and may be better than morphine in patients with renal impairment due to the decreased production of active metabolites.': defaultdict(int,
#              {}),
#  'D018847': defaultdict(int, {}),
#  'opioid': defaultdict(int, {}),
#  'Opioid Peptides': defaultdict(int, {}),
#  'Peptides, Opioid': defaultdict(int, {}),
#  'Opiate Peptides': defaultdict(int, {}),
#  'Peptides, Opiate': defaultdict(int, {}),
#  'Opioid Peptide': defaultdict(int, {}),
#  'Peptide, Opioid': defaultdict(int, {}),
#  'Opiates, Endogenous': defaultdict(int, {}),
#  'Endogenous Opiates': defaultdict(int, {}),
#  'oxycodone': defaultdict(int, {}),
#  'The aim of this review is to outline the pharmacodynamic and pharmacokinetic properties, drug interactions, dosing rules, adverse effects, equianalgesic dose ratio with other opioids and clinical studies of oxycodone in patients with cancer pain.': defaultdict(int,
#              {}),
#  'Nefopam hydrochloride (Acupan) is a potent non-opioid analgesic widely used for the relief of moderate to severe postoperative pain.': defaultdict(int,
#              {}),
#  'Nefopam hydrochloride': defaultdict(int, {}),
#  'When taken in overdose, nefopam has been reported to cause cardiac conduction abnormalities, cerebral oedema, fever and renal failure.': defaultdict(int,
#              {}),
#  'CNS respiratory depression': defaultdict(int, {}),
#  'MENTAL_HEALTH': defaultdict(int, {}),
#  'Twenty-three patients (40%) had ingested only pentazocine and did not have the classic opioid toxidrome of CNS and respiratory depression with miosis.': defaultdict(int,
#              {}),
#  'NEW00057': defaultdict(int, {}),
#  'alcohol': defaultdict(int, {}),
#  'Patients who had ingested pentazocine with alcohol, a sedative/hypnotic drug, or an antihistamine, showed increased toxicity, including apnea, deep coma, and recurrent seizures.': defaultdict(int,
#              {}),
#  'D064829': defaultdict(int, {}),
#  'Alcohol Abstinence': defaultdict(int, {}),
#  'Abstinence, Alcohol': defaultdict(int, {}),
#  'Abstinence from Ethanol': defaultdict(int, {}),
#  'Abstinence from Ethanols': defaultdict(int, {}),
#  'Ethanol Abstinence': defaultdict(int, {}),
#  'Abstinence, Ethanol': defaultdict(int, {}),
#  'coma inadequate respirations': defaultdict(int, {}),
#  'Three of five patients with coma and inadequate respirations responded to IV naloxone in doses of 0.4 to 1.2 mg.': defaultdict(int,
#              {}),
#  'NEW00060': defaultdict(int, {}),
#  'opioid analgesics': defaultdict(int, {}),
#  'Chronic use (>90 Days) of opioid analgesics significantly increases the risk of development of new depression episodes (NDE).': defaultdict(int,
#              {}),
#  'D018712': defaultdict(int, {}),
#  'Analgesics, Non-Narcotic': defaultdict(int, {}),
#  'Analgesics, Non Narcotic': defaultdict(int, {}),
#  'Non-Narcotic Analgesics': defaultdict(int, {}),
#  'Non-Opioid Analgesic': defaultdict(int, {}),
#  'Analgesic, Non-Opioid': defaultdict(int, {}),
#  'Nonopioid Analgesics': defaultdict(int, {}),
#  'Non-Opioid Analgesics': defaultdict(int, {}),
#  'Analgesics, Non-Opioid': defaultdict(int, {}),
#  'Non Opioid Analgesics': defaultdict(int, {}),
#  'Analgesics, Nonnarcotic': defaultdict(int, {}),
#  'Nonnarcotic Analgesics': defaultdict(int, {}),
#  'Analgesics, Nonopioid': defaultdict(int, {}),
#  'Non Opioid Analgesic': defaultdict(int, {}),
#  'Analgesic, Non Opioid': defaultdict(int, {}),
#  'Opioid Analgesic, Non': defaultdict(int, {}),
#  'Nonopioid Analgesic': defaultdict(int, {}),
#  'Analgesic, Nonopioid': defaultdict(int, {}),
#  'buprenorphine': defaultdict(int, {}),
#  'Two medication treatments (buprenorphine and naltrexone) are effective for treating opioid use disorder (OUD) in office-based settings but are seldom prescribed to adolescents.': defaultdict(int,
#              {}),
#  'D002047': defaultdict(int, {}),
#  'Buprenorphine': defaultdict(int, {}),
#  'Buprenex': defaultdict(int, {}),
#  'Prefin': defaultdict(int, {}),
#  'Subutex': defaultdict(int, {}),
#  'Buprex': defaultdict(int, {}),
#  'Temgesic': defaultdict(int, {}),
#  'Temgésic': defaultdict(int, {}),
#  '6029-M': defaultdict(int, {}),
#  '6029 M': defaultdict(int, {}),
#  '6029M': defaultdict(int, {}),
#  'RX-6029-M': defaultdict(int, {}),
#  'RX 6029 M': defaultdict(int, {}),
#  'RX6029M': defaultdict(int, {}),
#  'Buprenorphine Hydrochloride': defaultdict(int, {}),
#  'Hydrochloride, Buprenorphine': defaultdict(int, {}),
#  'post-traumatic stress disorder': defaultdict(int, {}),
#  'Patients with post-traumatic stress disorder (PTSD) have complex and multiple symptoms, including anxiety, insomnia, and co-occurring pain, often treated with opioids and benzodiazepines.': defaultdict(int,
#              {}),
#  'D013313': defaultdict(int, {}),
#  'Stress Disorders, Post-Traumatic': defaultdict(int, {}),
#  'Post-Traumatic Stress Disorder': defaultdict(int, {}),
#  'Stress Disorder, Post-Traumatic': defaultdict(int, {}),
#  'Neuroses, Post-Traumatic': defaultdict(int, {}),
#  'Neuroses, Post Traumatic': defaultdict(int, {}),
#  'Post-Traumatic Neuroses': defaultdict(int, {}),
#  'PTSD': defaultdict(int, {}),
#  'Neuroses, Posttraumatic': defaultdict(int, {}),
#  'Posttraumatic Neuroses': defaultdict(int, {}),
#  'Post-Traumatic Stress Disorders': defaultdict(int, {}),
#  'Post Traumatic Stress Disorders': defaultdict(int, {}),
#  'Posttraumatic Stress Disorders': defaultdict(int, {}),
#  'Posttraumatic Stress Disorder': defaultdict(int, {}),
#  'Stress Disorder, Posttraumatic': defaultdict(int, {}),
#  'Stress Disorders, Posttraumatic': defaultdict(int, {}),
#  'Post Traumatic Stress Disorder': defaultdict(int, {}),
#  'Stress Disorder, Post Traumatic': defaultdict(int, {}),
#  'Delayed Onset Post-Traumatic Stress Disorder': defaultdict(int, {}),
#  'Delayed Onset Post Traumatic Stress Disorder': defaultdict(int, {}),
#  'Chronic Post-Traumatic Stress Disorder': defaultdict(int, {}),
#  'Chronic Post Traumatic Stress Disorder': defaultdict(int, {}),
#  'Moral Injury': defaultdict(int, {}),
#  'Injury, Moral': defaultdict(int, {}),
#  'Moral Injuries': defaultdict(int, {}),
#  'Acute Post-Traumatic Stress Disorder': defaultdict(int, {}),
#  'Acute Post Traumatic Stress Disorder': defaultdict(int, {}),
#  'chronic stress': defaultdict(int, {}),
#  'In this paper, we study whether chronic stress induced by repetition of acute stress protocols affects long-term feeding behavior and growth performance in sea bass and whether exogenous cortisol may induce stress-like changes in these parameters.': defaultdict(int,
#              {}),
#  'NEW00065': defaultdict(int, {}),
#  'antidepressant medications': defaultdict(int, {}),
#  'For example, antidepressant medications may be efficacious in the treatment of depression but only work for so long as they are taken.': defaultdict(int,
#              {}),
#  'NEW00066': defaultdict(int, {}),
#  'sialidase inhibitor oseltamivir': defaultdict(int, {}),
#  'Preclinical reports suggest that the sialidase inhibitor oseltamivir induces a platelet response in the treatment of immune thrombocytopenia.': defaultdict(int,
#              {}),
#  'NEW00067': defaultdict(int, {}),
#  'A. glehni extract': defaultdict(int, {}),
#  'Phytochemical isolation from A. glehni extract yielded three kaempferol glycosides.': defaultdict(int,
#              {}),
#  'NEW00068': defaultdict(int, {}),
#  'phenylpropanoid moieties': defaultdict(int, {}),
#  'The water-ethanol (7:3) extract and both p-coumaric acid and caffeic acid, phenylpropanoid moieties of CQs, had sedative effects in pentobarbital-induced sleeping time in mice and anticonvulsant effects in pentylenetetrazole-induced mice.': defaultdict(int,
#              {}),
#  'NEW00070': defaultdict(int, {}),
#  'water-ethanol extract': defaultdict(int, {}),
#  'NEW00072': defaultdict(int, {}),
#  'p-coumaric acid': defaultdict(int, {}),
#  'C522975': defaultdict(int, {}),
#  'p-coumaric acid glucoside [Supplementary Concept]': defaultdict(int, {}),
#  'Coumaric Acids': defaultdict(int, {}),
#  'Glucosides': defaultdict(int, {}),
#  'Dyskinesia': defaultdict(int, {}),
#  'Dyskinesia appeared several days after intravenous administration of ranitidine for stress ulcer prophylaxis.': defaultdict(int,
#              {}),
#  'D018726': defaultdict(int, {}),
#  'Anti-Dyskinesia Agents': defaultdict(int, {}),
#  'Agents, Anti-Dyskinesia': defaultdict(int, {}),
#  'Anti Dyskinesia Agents': defaultdict(int, {}),
#  'Movement Disorder Agents': defaultdict(int, {}),
#  'Agents, Movement Disorder': defaultdict(int, {}),
#  'Disorder Agents, Movement': defaultdict(int, {}),
#  'ranitidine': defaultdict(int, {}),
#  'D011899': defaultdict(int, {}),
#  'Ranitidine': defaultdict(int, {}),
#  'Ranitidin': defaultdict(int, {}),
#  "N (2-(((5-((Dimethylamino)methyl)-2-furanyl)methyl)thio)ethyl)-N'-methyl-2-nitro-1,1-ethenediamine": defaultdict(int,
#              {}),
#  'Biotidin': defaultdict(int, {}),
#  'Ranisen': defaultdict(int, {}),
#  'Sostril': defaultdict(int, {}),
#  'Zantac': defaultdict(int, {}),
#  'Zantic': defaultdict(int, {}),
#  'AH-19065': defaultdict(int, {}),
#  'AH 19065': defaultdict(int, {}),
#  'AH19065': defaultdict(int, {}),
#  'Ranitidine Hydrochloride': defaultdict(int, {}),
#  'Hydrochloride, Ranitidine': defaultdict(int, {}),
#  'histamine receptor blocker therapy': defaultdict(int, {}),
#  'Cessation of histamine receptor blocker therapy for 48 hours was associated with return of normal cognitive function and disappearance of abnormal movements.': defaultdict(int,
#              {}),
#  'NEW00074': defaultdict(int, {}),
#  'ethanol E. senticosus root extract': defaultdict(int, {}),
#  'The 75% ethanol E. senticosus root extract proved to be the most effective, both as a cure and in the prophylaxis of nosemosis.': defaultdict(int,
#              {}),
#  'NEW00075': defaultdict(int, {}),
#  'Eleutherococcus senticosus': defaultdict(int, {}),
#  'Therefore, Eleutherococcus senticosus, and its active compounds, eleutherosides, are considered the most powerful adaptogens, in the pool of all extracts that were selected for screening, for supporting immunity and improving resistance of honeybees.': defaultdict(int,
#              {}),
#  'C000713177': defaultdict(int, {}),
#  'Siberian ginseng root [Supplementary Concept]': defaultdict(int, {}),
#  'Plant Extracts': defaultdict(int, {}),
#  'Eleutherococcus': defaultdict(int, {}),
#  'fatigue': defaultdict(int, {}),
#  'Strong scientific evidence is available for Rhodiola rosea SHR-5 extract, which improved attention, cognitive function and mental performance in fatigue and in chronic fatigue syndrome.': defaultdict(int,
#              {}),
#  'D018763': defaultdict(int, {}),
#  'Muscle Fatigue': defaultdict(int, {}),
#  'Muscular Fatigue': defaultdict(int, {}),
#  'Fatigue, Muscular': defaultdict(int, {}),
#  'Fatigue, Muscle': defaultdict(int, {}),
#  'Serotonergic antagonists': defaultdict(int, {}),
#  'Serotonergic antagonists and alpha-adrenoceptor antagonists, for example, are also being considered as potential options in the treatment of mental diseases such as schizophrenia.': defaultdict(int,
#              {}),
#  'NEW00077': defaultdict(int, {}),
#  'alpha-adrenoceptor antagonists': defaultdict(int, {}),
#  'NEW00078': defaultdict(int, {}),
#  'PDE5-Is': defaultdict(int, {}),
#  'Phosphodiesterase isoenzymes 5 inhibitors (PDE5-Is) are the first-line therapy for erectile dysfunction (ED).': defaultdict(int,
#              {}),
#  'NEW00079': defaultdict(int, {}),
#  'Phosphodiesterase isoenzymes 5 inhibitors': defaultdict(int, {}),
#  'PDE5-Is are also the first rehabilitation strategy for postoperation or postradiotherapy ED for prostate cancer patients.': defaultdict(int,
#              {}),
#  'PDE5-Is, especially combined with α-adrenoceptor antagonists, are very effective for benign prostatic hyperplasia (BPH) except on maximum urinary flow rate (Q max ) with tadalafil recently proved for BPH with/without ED.': defaultdict(int,
#              {}),
#  "Furthermore, PDE5-Is are currently under various phases of clinical or preclinical researches with promising potential for other urinary and genital illnesses, such as priapism, premature ejaculation, urinary tract calculi, overactive bladder, Peyronie's disease, and female sexual dysfunction.": defaultdict(int,
#              {}),
#  'alpha adrenoceptor antagonists': defaultdict(int, {}),
#  'While alpha adrenoceptor antagonists and 5-alpha-reductase inhibitors deliver improvement in symptom relief in benign prostatic hyperplasia sufferers, the availability of efficacious and well-tolerated medicines to treat incontinence is less well served.': defaultdict(int,
#              {}),
#  'NEW00084': defaultdict(int, {}),
#  'α1-adrenoceptor antagonists': defaultdict(int, {}),
#  'Two decades following the discovery that α1-adrenoceptor antagonists suppress prostate tumor growth at the molecular and cellular level, the impact of α-blockade as re-purposed treatment strategy in the medical management of prostate cancer is gradually being recognized.': defaultdict(int,
#              {}),
#  'NEW00086': defaultdict(int, {}),
#  'α1-adrenoceptor antagonists are clinically indicated as first-line therapies for the relief of BPH, hypertension, and post-traumatic stress disorder (PTSD).': defaultdict(int,
#              {}),
#  'quinazoline based compounds': defaultdict(int, {}),
#  'Optimization of quinazoline based compounds (doxazosin) to exploit pharmacologic targeting of tumor growth and vascularization revealed high efficacy of the lead novel compound DZ-50 against prostate tumors.': defaultdict(int,
#              {}),
#  'NEW00089': defaultdict(int, {}),
#  'doxazosin': defaultdict(int, {}),
#  'D064751': defaultdict(int, {}),
#  'compounds': defaultdict(int, {}),
#  'Ammonium Compounds': defaultdict(int, {}),
#  'Ammonium': defaultdict(int, {}),
#  'α-blockade': defaultdict(int, {}),
#  'This review discusses the experimental and pre-clinical evidence on the impact of α-blockade on prostate cancer.': defaultdict(int,
#              {}),
#  'NEW00091': defaultdict(int, {}),
#  'Muscarinic receptor antagonists': defaultdict(int, {}),
#  'Introduction: Muscarinic receptor antagonists, 5α-reductase inhibitors and α1-adrenoceptor antagonists are frequently used drug classes for the treatment of lower urinary tract symptoms including those of overactive bladder syndrome and benign prostatic enlargement/benign prostatic obstruction.': defaultdict(int,
#              {}),
#  'NEW00092': defaultdict(int, {}),
#  'cytokinins': defaultdict(int, {}),
#  'Our aim is to provide a comprehensive overview of recent findings on the mechanisms by which cytokinins act as central regulators of plant development and stress reactions, and highlight topics for future research.': defaultdict(int,
#              {}),
#  'D003583': defaultdict(int, {}),
#  'Cytokinins': defaultdict(int, {}),
#  'Cytokinin': defaultdict(int, {}),
#  'xanthine dehydrogenase': defaultdict(int, {}),
#  '(1) Nitrate reductase catalyses the key step in inorganic nitrogen assimilation, (2) aldehyde oxidase(s) have been shown to catalyse the last step in the biosynthesis of the phytohormone abscisic acid, (3) xanthine dehydrogenase is involved in purine catabolism and stress reactions, and (4) sulphite oxidase is probably involved in detoxifying excess sulphite.': defaultdict(int,
#              {}),
#  'D014968': defaultdict(int, {}),
#  'Xanthine Dehydrogenase': defaultdict(int, {}),
#  'Dehydrogenase, Xanthine': defaultdict(int, {}),
#  'Purine Hydroxylase I': defaultdict(int, {}),
#  'Xanthine Oxidoreductase': defaultdict(int, {}),
#  'Oxidoreductase, Xanthine': defaultdict(int, {}),
#  'sulphite oxidase': defaultdict(int, {}),
#  'D050876': defaultdict(int, {}),
#  'Sulfite Oxidase': defaultdict(int, {}),
#  'Oxidase, Sulfite': defaultdict(int, {}),
#  'Sulphite Oxidase': defaultdict(int, {}),
#  'Oxidase, Sulphite': defaultdict(int, {}),
#  'ABA': defaultdict(int, {}),
#  'Here we provide evidence that ABA stimulates several functional activities of the murine microglial cell line N9 (NO and tumor necrosis factor-alpha production, cell migration) through the second messenger cyclic ADP-ribose and an increase of intracellular calcium.': defaultdict(int,
#              {}),
#  'NEW00098': defaultdict(int, {}),
#  'Activity-based anorexia': defaultdict(int, {}),
#  'Trans Fatty Acid TFA intake': defaultdict(int, {}),
#  'Trans Fatty Acid (TFA) intake is a risk factor for coronary heart diseases and cancer.': defaultdict(int,
#              {}),
#  'NEW00101': defaultdict(int, {}),
#  'psychotic disorders': defaultdict(int, {}),
#  'Persons with schizophrenia and other psychotic disorders have a high prevalence of obesity, impaired glucose tolerance, and lipid abnormalities, particularly hypertriglyceridemia and low high-density lipoprotein.': defaultdict(int,
#              {}),
#  'D019967': defaultdict(int, {}),
#  'Schizophrenia Spectrum and Other Psychotic Disorders': defaultdict(int, {}),
#  'Schizophrenia and Disorders with Psychotic Features': defaultdict(int, {}),
#  'MSUD metabolites': defaultdict(int, {}),
#  'We propose that this presentation resembles the intermittent neuropathy observed in pyruvate dehydrogenase deficiency and may reflect secondary inhibition of pyruvate dehydrogenase activity by MSUD metabolites.': defaultdict(int,
#              {}),
#  'NEW00102': defaultdict(int, {}),
#  'brain kynurenic acid levels': defaultdict(int, {}),
#  'Elevation of brain kynurenic acid levels reduces the release of neurotransmitters such as dopamine and glutamate, and kynurenic acid is considered to be involved in psychiatric disorders such as schizophrenia and depression.': defaultdict(int,
#              {}),
#  'NEW00104': defaultdict(int, {}),
#  'kynurenic acid production': defaultdict(int, {}),
#  'Thus, the control of kynurenine pathway, especially kynurenic acid production, in the brain is an important target for the improvement of brain function or the effective treatment of brain disorders.': defaultdict(int,
#              {}),
#  'NEW00105': defaultdict(int, {}),
#  'kynurenine pathway': defaultdict(int, {}),
#  'NEW00106': defaultdict(int, {}),
#  'BCAA': defaultdict(int, {}),
#  'BCAA promoted resilience to chronic stress, rescued social avoidance behaviors and increased hippocampal BDNF levels and TRKB activation.': defaultdict(int,
#              {}),
#  'D000597': defaultdict(int, {}),
#  'Branched-chain amino acids': defaultdict(int, {}),
#  'Amino Acids, Branched-Chain': defaultdict(int, {}),
#  'Acids, Branched-Chain Amino': defaultdict(int, {}),
#  'Branched-Chain Amino Acids': defaultdict(int, {}),
#  'Amino Acids, Branched Chain': defaultdict(int, {}),
#  'Branched-Chain Amino Acid': defaultdict(int, {}),
#  'Acid, Branched-Chain Amino': defaultdict(int, {}),
#  'Amino Acid, Branched-Chain': defaultdict(int, {}),
#  'Branched Chain Amino Acid': defaultdict(int, {}),
#  'amino acid transport': defaultdict(int, {}),
#  'We conclude that regulation of amino acid transport in β-cells during ER stress involves responses leading to increased protein synthesis, which can be protective during acute stress but can lead to apoptosis during chronic stress.': defaultdict(int,
#              {}),
#  'D050495': defaultdict(int, {}),
#  'Vesicular Inhibitory Amino Acid Transport Proteins': defaultdict(int, {}),
#  'VIAAT Transporter Proteins': defaultdict(int, {}),
#  'Transporter Proteins, VIAAT': defaultdict(int, {}),
#  'Vesicular Inhibitory Amino Acid Transporter Proteins': defaultdict(int, {}),
#  'VGAT Transporter Proteins': defaultdict(int, {}),
#  'Transporter Proteins, VGAT': defaultdict(int, {}),
#  'Vesicular GABA-Glycine Transport Proteins': defaultdict(int, {}),
#  'Vesicular GABA Glycine Transport Proteins': defaultdict(int, {}),
#  'Vesicular GABA-Glycine Transporter Proteins': defaultdict(int, {}),
#  'Vesicular GABA Glycine Transporter Proteins': defaultdict(int, {}),
#  'neurological sequelae': defaultdict(int, {}),
#  'Recent literature suggests that the neurological sequelae may be due to the brain-specific roles of BCAAs.': defaultdict(int,
#              {}),
#  'NEW00107': defaultdict(int, {}),
#  'BCAA metabolism': defaultdict(int, {}),
#  'Finally, we will discuss recent evidence that implicates the relevance of BCAA metabolism in other neurological disorders.': defaultdict(int,
#              {}),
#  'NEW00108': defaultdict(int, {}),
#  'BCAAs': defaultdict(int, {}),
#  'An understanding of the role of BCAAs in the central nervous system may facilitate future identification of novel therapeutic approaches in MSUD and a broad range of neurological disorders.': defaultdict(int,
#              {}),
#  'branched-chain amino acids': defaultdict(int, {}),
#  'VPA': defaultdict(int, {}),
#  'This novel finding indicates that VPA, through the displacement of TRP from its protein-binding sites, could disturb the BCAA/AAA ratio, with central nervous system consequences, including the possible contribution to VPAs effects in affective disorders.': defaultdict(int,
#              {}),
#  'NEW00109': defaultdict(int, {}),
#  'Objectives Valproic acid': defaultdict(int, {}),
#  'Diabetic ketoacidosis': defaultdict(int, {}),
#  'Diabetic ketoacidosis (DKA) is a severe metabolic disturbance of insulin-dependent diabetes mellitus (IDDM) which has a significant effect on amino acid metabolism.': defaultdict(int,
#              {}),
#  'D016883': defaultdict(int, {}),
#  'Diabetic Ketoacidosis': defaultdict(int, {}),
#  'Diabetic Ketoacidoses': defaultdict(int, {}),
#  'Ketoacidoses, Diabetic': defaultdict(int, {}),
#  'Diabetic Acidosis': defaultdict(int, {}),
#  'DKA Diabetic Ketoacidosis': defaultdict(int, {}),
#  'DKA Diabetic Ketoacidoses': defaultdict(int, {}),
#  'Diabetic Ketoacidosis, DKA': defaultdict(int, {}),
#  'Ketoacidosis, DKA Diabetic': defaultdict(int, {}),
#  'Ketoacidosis, Diabetic': defaultdict(int, {}),
#  'Ketosis, Diabetic': defaultdict(int, {}),
#  'Acidosis, Diabetic': defaultdict(int, {}),
#  'Acidoses, Diabetic': defaultdict(int, {}),
#  'Diabetic Acidoses': defaultdict(int, {}),
#  'Diabetic Ketosis': defaultdict(int, {}),
#  'Diabetic Ketoses': defaultdict(int, {}),
#  'Ketoses, Diabetic': defaultdict(int, {}),
#  'IDDM': defaultdict(int, {}),
#  'Amino acids serve as precursors for various neurotransmitters which are involved in affective disorders, and patients with IDDM are known to have an increased prevalence of affective disorders.': defaultdict(int,
#              {}),
#  'D003922': defaultdict(int, {}),
#  'insulin-dependent diabetes mellitus': defaultdict(int, {}),
#  'Diabetes Mellitus, Type 1': defaultdict(int, {}),
#  'Diabetes Mellitus, Insulin-Dependent': defaultdict(int, {}),
#  'Diabetes Mellitus, Insulin Dependent': defaultdict(int, {}),
#  'Insulin-Dependent Diabetes Mellitus': defaultdict(int, {}),
#  'Diabetes Mellitus, Juvenile-Onset': defaultdict(int, {}),
#  'Diabetes Mellitus, Juvenile Onset': defaultdict(int, {}),
#  'Juvenile-Onset Diabetes Mellitus': defaultdict(int, {}),
#  'Juvenile-Onset Diabetes': defaultdict(int, {}),
#  'Diabetes, Juvenile-Onset': defaultdict(int, {}),
#  'Juvenile Onset Diabetes': defaultdict(int, {}),
#  'Diabetes Mellitus, Sudden-Onset': defaultdict(int, {}),
#  'Diabetes Mellitus, Sudden Onset': defaultdict(int, {}),
#  'Sudden-Onset Diabetes Mellitus': defaultdict(int, {}),
#  'Type 1 Diabetes Mellitus': defaultdict(int, {}),
#  'Diabetes Mellitus, Insulin-Dependent, 1': defaultdict(int, {}),
#  'Insulin-Dependent Diabetes Mellitus 1': defaultdict(int, {}),
#  'Insulin Dependent Diabetes Mellitus 1': defaultdict(int, {}),
#  'Type 1 Diabetes': defaultdict(int, {}),
#  'Diabetes, Type 1': defaultdict(int, {}),
#  'Diabetes Mellitus, Type I': defaultdict(int, {}),
#  'Diabetes, Autoimmune': defaultdict(int, {}),
#  'Autoimmune Diabetes': defaultdict(int, {}),
#  'Diabetes Mellitus, Brittle': defaultdict(int, {}),
#  'Brittle Diabetes Mellitus': defaultdict(int, {}),
#  'Diabetes Mellitus, Ketosis-Prone': defaultdict(int, {}),
#  'Diabetes Mellitus, Ketosis Prone': defaultdict(int, {}),
#  'Ketosis-Prone Diabetes Mellitus': defaultdict(int, {}),
#  'The well-known increase in the concentrations of the glucogenic amino acids and the decrease in the branched-chain amino acids were observed in response to treatment of DKA.': defaultdict(int,
#              {}),
#  'DKA': defaultdict(int, {}),
#  'Our results indicate that DKA causes a depletion of plasma tryptophan.': defaultdict(int,
#              {}),
#  'diabetic ketoacidosis': defaultdict(int, {}),
#  'ammonia': defaultdict(int, {}),
#  'Branched-chain amino acids (BCAA) have been reported to improve the symptoms of HE induced by hyperammonemia; however, we recently reported that ammonia increases intracellular levels of BCAA and exerts toxic effects on astrocytes.': defaultdict(int,
#              {}),
#  'D010650': defaultdict(int, {}),
#  'Phenylalanine Ammonia-Lyase': defaultdict(int, {}),
#  'Ammonia-Lyase, Phenylalanine': defaultdict(int, {}),
#  'Phenylalanine Ammonia Lyase': defaultdict(int, {}),
#  'Phenylalanine-Tyrosine Ammonia-lyase': defaultdict(int, {}),
#  'Ammonia-lyase, Phenylalanine-Tyrosine': defaultdict(int, {}),
#  'Phenylalanine Tyrosine Ammonia lyase': defaultdict(int, {}),
#  'Urea cycle disorders': defaultdict(int, {}),
#  'Urea cycle disorders (UCDs) are a group of rare inherited metabolic diseases causing hyperammonemic encephalopathy.': defaultdict(int,
#              {}),
#  'D056806': defaultdict(int, {}),
#  'Urea Cycle Disorders, Inborn': defaultdict(int, {}),
#  'Urea Cycle Disorders': defaultdict(int, {}),
#  'Disorder, Urea Cycle': defaultdict(int, {}),
#  'Disorders, Urea Cycle': defaultdict(int, {}),
#  'Urea Cycle Disorder': defaultdict(int, {}),
#  'Inborn Urea Cycle Disorder': defaultdict(int, {}),
#  'inborn errors': defaultdict(int, {}),
#  'Urea cycle disorders (UCDs), inborn errors of hepatocyte metabolism, cause hyperammonemia and lead to neurocognitive deficits, coma, and even death.': defaultdict(int,
#              {}),
#  'D043202': defaultdict(int, {}),
#  'Steroid Metabolism, Inborn Errors': defaultdict(int, {}),
#  'Inborn Errors of Steroid Metabolism': defaultdict(int, {}),
#  'Congenital Errors of Steroid Metabolism': defaultdict(int, {}),
#  'Steroid Metabolic Diseases, Inborn': defaultdict(int, {}),
#  'Sodium 4-phenylbutyrate': defaultdict(int, {}),
# ...
#              {}),
#  'NEW00122': defaultdict(int, {}),
#  'anxiety': defaultdict(int, {}),
#  'Aggression, anxiety, depression, personality disorders, and psychosis, observed on withdrawal of AAS or with use of large doses, can be caused by decreased serotonin synthesis due to TDO induction on withdrawal, excess Trp inhibiting the 2 enzymes of serotonin synthesis, and increased cerebral levels of neuroactive kynurenines.': defaultdict(int,
#              {}),
#  'NEW00012': defaultdict(int, {}),
#  'unlearned fear': defaultdict(int, {}),
#  'Aggression': defaultdict(int, {}),
#  'D000374': defaultdict(int, {}),
#  'Aggressions': defaultdict(int, {}),
#  'The resultant changes in amino acid metabolism may be implicated in the genesis of the neuropsychiatric abnormalities and the deterioration in nutritional status commonly observed in patients with hepatic failure.': defaultdict(int,
#              {}),
#  'plasma amino acid levels': defaultdict(int, {}),
#  'To investigate the relation between plasma amino acid levels and mental fatigue, we measured the plasma concentrations of 20 amino acids in 9 healthy volunteers before and after a fatigue-inducing mental task session for 8 hr.': defaultdict(int,
#              {}),
#  'NEW00130': defaultdict(int, {}),
#  'mental fatigue': defaultdict(int, {}),
#  'D005222': defaultdict(int, {}),
#  'Mental Fatigue': defaultdict(int, {}),
#  'Fatigue, Mental': defaultdict(int, {}),
#  'These results indicate that mental fatigue may be characterized by a decrease in the plasma level of these amino acids.': defaultdict(int,
#              {}),
#  'Alzheimer disease': defaultdict(int, {}),
#  'An association between both Alzheimer disease and Parkinson s disease and the 2-oxoglutarate dehydrogenase gene has been reported.': defaultdict(int,
#              {}),
#  'D000544': defaultdict(int, {}),
#  'Alzheimer Disease': defaultdict(int, {}),
#  'Alzheimer Dementia': defaultdict(int, {}),
#  'Alzheimer Dementias': defaultdict(int, {}),
#  'Dementia, Alzheimer': defaultdict(int, {}),
#  "Alzheimer's Disease": defaultdict(int, {}),
#  'Dementia, Senile': defaultdict(int, {}),
#  'Senile Dementia': defaultdict(int, {}),
#  'Dementia, Alzheimer Type': defaultdict(int, {}),
#  'Alzheimer Type Dementia': defaultdict(int, {}),
#  'Alzheimer-Type Dementia (ATD)': defaultdict(int, {}),
#  'Alzheimer Type Dementia (ATD)': defaultdict(int, {}),
#  'Dementia, Alzheimer-Type (ATD)': defaultdict(int, {}),
#  'Alzheimer Type Senile Dementia': defaultdict(int, {}),
#  'Primary Senile Degenerative Dementia': defaultdict(int, {}),
#  'Dementia, Primary Senile Degenerative': defaultdict(int, {}),
#  'Alzheimer Sclerosis': defaultdict(int, {}),
#  'Sclerosis, Alzheimer': defaultdict(int, {}),
#  'Alzheimer Syndrome': defaultdict(int, {}),
#  "Alzheimer's Diseases": defaultdict(int, {}),
#  'Alzheimer Diseases': defaultdict(int, {}),
#  'Alzheimers Diseases': defaultdict(int, {}),
#  'Senile Dementia, Alzheimer Type': defaultdict(int, {}),
#  'Acute Confusional Senile Dementia': defaultdict(int, {}),
#  'Senile Dementia, Acute Confusional': defaultdict(int, {}),
#  'Dementia, Presenile': defaultdict(int, {}),
#  'Presenile Dementia': defaultdict(int, {}),
#  'Alzheimer Disease, Late Onset': defaultdict(int, {}),
#  'Late Onset Alzheimer Disease': defaultdict(int, {}),
#  "Alzheimer's Disease, Focal Onset": defaultdict(int, {}),
#  "Focal Onset Alzheimer's Disease": defaultdict(int, {}),
#  'Familial Alzheimer Disease (FAD)': defaultdict(int, {}),
#  'Alzheimer Disease, Familial (FAD)': defaultdict(int, {}),
#  'Familial Alzheimer Diseases (FAD)': defaultdict(int, {}),
#  'Alzheimer Disease, Early Onset': defaultdict(int, {}),
#  'Early Onset Alzheimer Disease': defaultdict(int, {}),
#  'Presenile Alzheimer Dementia': defaultdict(int, {}),
#  's disease': defaultdict(int, {}),
#  'D000755': defaultdict(int, {}),
#  'Anemia, Sickle Cell': defaultdict(int, {}),
#  'Anemias, Sickle Cell': defaultdict(int, {}),
#  'Sickle Cell Anemias': defaultdict(int, {}),
#  'Hemoglobin S Disease': defaultdict(int, {}),
#  'Disease, Hemoglobin S': defaultdict(int, {}),
#  'Hemoglobin S Diseases': defaultdict(int, {}),
#  'Sickle Cell Anemia': defaultdict(int, {}),
#  'Sickle Cell Disorders': defaultdict(int, {}),
#  'Cell Disorder, Sickle': defaultdict(int, {}),
#  'Cell Disorders, Sickle': defaultdict(int, {}),
#  'Sickle Cell Disorder': defaultdict(int, {}),
#  'Sickling Disorder Due to Hemoglobin S': defaultdict(int, {}),
#  'HbS Disease': defaultdict(int, {}),
#  'Sickle Cell Disease': defaultdict(int, {}),
#  'Cell Disease, Sickle': defaultdict(int, {}),
#  'Cell Diseases, Sickle': defaultdict(int, {}),
#  'Sickle Cell Diseases': defaultdict(int, {}),
#  'At 7.5 months of age, the plasma heterophil/lymphocyte (H/L) ratio was measured before and 72 h after feather harvesting and feather clipping to determine acute stress responses, while chronic stress was measured by quantification of corticosterone (CORT) concentrations in the floss feathers of the birds.': defaultdict(int,
#              {}),
#  'alcohol dependence': defaultdict(int, {}),
#  'Alcohol-dependent animals display enhanced stress responsivity, reward thresholds, and alcohol self-administration during alcohol withdrawal, and some of these aspects of alcohol dependence may be mediated by activation of brain norepinephrine (NE) systems.': defaultdict(int,
#              {}),
#  'D000437': defaultdict(int, {}),
#  'Alcoholism': defaultdict(int, {}),
#  'Alcohol Dependence': defaultdict(int, {}),
#  'Dependence, Alcohol': defaultdict(int, {}),
#  'Alcohol Addiction': defaultdict(int, {}),
#  'Addiction, Alcohol': defaultdict(int, {}),
#  'Alcoholic Intoxication, Chronic': defaultdict(int, {}),
#  'Chronic Alcoholic Intoxication': defaultdict(int, {}),
#  'Intoxication, Chronic Alcoholic': defaultdict(int, {}),
#  'Alcohol Abuse': defaultdict(int, {}),
#  'Abuse, Alcohol': defaultdict(int, {}),
#  'Ethanol Abuse': defaultdict(int, {}),
#  'Abuse, Ethanol': defaultdict(int, {}),
#  'Alcohol Use Disorder': defaultdict(int, {}),
#  'Alcohol Use Disorders': defaultdict(int, {}),
#  'Use Disorders, Alcohol': defaultdict(int, {}),
#  'beta-adrenoceptor antagonists': defaultdict(int, {}),
#  'In neuropsychiatry, beta-adrenoceptor antagonists have been used for the treatment of acute stress reactions and generalised anxiety, essential tremor and prophylaxis of migraine.': defaultdict(int,
#              {}),
#  'D000319': defaultdict(int, {}),
#  'Adrenergic beta-Antagonists': defaultdict(int, {}),
#  'Adrenergic beta Antagonists': defaultdict(int, {}),
#  'beta-Antagonists, Adrenergic': defaultdict(int, {}),
#  'Adrenergic beta-Receptor Blockader': defaultdict(int, {}),
#  'Adrenergic beta Receptor Blockader': defaultdict(int, {}),
#  'Blockader, Adrenergic beta-Receptor': defaultdict(int, {}),
#  'beta-Receptor Blockader, Adrenergic': defaultdict(int, {}),
#  'beta-Adrenergic Antagonist': defaultdict(int, {}),
#  'Antagonist, beta-Adrenergic': defaultdict(int, {}),
#  'beta Adrenergic Antagonist': defaultdict(int, {}),
#  'beta-Adrenergic Blocker': defaultdict(int, {}),
#  'Blocker, beta-Adrenergic': defaultdict(int, {}),
#  'beta Adrenergic Blocker': defaultdict(int, {}),
#  'beta-Adrenergic Antagonists': defaultdict(int, {}),
#  'Antagonists, beta-Adrenergic': defaultdict(int, {}),
#  'beta Adrenergic Antagonists': defaultdict(int, {}),
#  'beta-Adrenoceptor Antagonists': defaultdict(int, {}),
#  'Antagonists, beta-Adrenoceptor': defaultdict(int, {}),
#  'beta Adrenoceptor Antagonists': defaultdict(int, {}),
#  'Adrenergic beta-Receptor Blockaders': defaultdict(int, {}),
#  'Adrenergic beta Receptor Blockaders': defaultdict(int, {}),
#  'Blockaders, Adrenergic beta-Receptor': defaultdict(int, {}),
#  'beta-Receptor Blockaders, Adrenergic': defaultdict(int, {}),
#  'beta-Adrenergic Receptor Blockaders': defaultdict(int, {}),
#  'Blockaders, beta-Adrenergic Receptor': defaultdict(int, {}),
#  'Receptor Blockaders, beta-Adrenergic': defaultdict(int, {}),
#  'beta Adrenergic Receptor Blockaders': defaultdict(int, {}),
#  'beta-Adrenergic Blocking Agents': defaultdict(int, {}),
#  'Agents, beta-Adrenergic Blocking': defaultdict(int, {}),
#  'Blocking Agents, beta-Adrenergic': defaultdict(int, {}),
#  'beta Adrenergic Blocking Agents': defaultdict(int, {}),
#  'beta-Adrenergic Blockers': defaultdict(int, {}),
#  'Blockers, beta-Adrenergic': defaultdict(int, {}),
#  'beta Adrenergic Blockers': defaultdict(int, {}),
#  'beta-Blockers, Adrenergic': defaultdict(int, {}),
#  'Adrenergic beta-Blockers': defaultdict(int, {}),
#  'beta Blockers, Adrenergic': defaultdict(int, {}),
#  'beta-Adrenergic Blocking Agent': defaultdict(int, {}),
#  'Agent, beta-Adrenergic Blocking': defaultdict(int, {}),
#  'Blocking Agent, beta-Adrenergic': defaultdict(int, {}),
#  'beta Adrenergic Blocking Agent': defaultdict(int, {}),
#  'beta-Adrenergic Receptor Blockader': defaultdict(int, {}),
#  'Blockader, beta-Adrenergic Receptor': defaultdict(int, {}),
#  'Receptor Blockader, beta-Adrenergic': defaultdict(int, {}),
#  'beta Adrenergic Receptor Blockader': defaultdict(int, {}),
#  'beta-Adrenoceptor Antagonist': defaultdict(int, {}),
#  'Antagonist, beta-Adrenoceptor': defaultdict(int, {}),
#  'beta Adrenoceptor Antagonist': defaultdict(int, {}),
#  'Adrenergic beta-Antagonist': defaultdict(int, {}),
#  'Adrenergic beta Antagonist': defaultdict(int, {}),
#  'beta-Antagonist, Adrenergic': defaultdict(int, {}),
#  'metoprolol': defaultdict(int, {}),
#  'For prophylactic treatment of migraine, beta-adrenoceptor antagonists such as propranolol, metoprolol, nadolol and atenolol are the drugs of first choice.': defaultdict(int,
#              {}),
#  'D008790': defaultdict(int, {}),
#  'Metoprolol': defaultdict(int, {}),
#  'Toprol': defaultdict(int, {}),
#  'Betaloc': defaultdict(int, {}),
#  'Betaloc-Astra': defaultdict(int, {}),
#  'Betaloc Astra': defaultdict(int, {}),
#  'Betalok': defaultdict(int, {}),
#  'CGP-2175': defaultdict(int, {}),
#  'CGP 2175': defaultdict(int, {}),
#  'CGP2175': defaultdict(int, {}),
#  'H 93-26': defaultdict(int, {}),
#  'H 93 26': defaultdict(int, {}),
#  'H 9326': defaultdict(int, {}),
#  'Metoprolol Tartrate': defaultdict(int, {}),
#  'Seloken': defaultdict(int, {}),
#  'Spesicor': defaultdict(int, {}),
#  'Spesikor': defaultdict(int, {}),
#  'Metoprolol Succinate': defaultdict(int, {}),
#  'Metoprolol CR-XL': defaultdict(int, {}),
#  'Metoprolol CR XL': defaultdict(int, {}),
#  'Toprol-XL': defaultdict(int, {}),
#  'Toprol XL': defaultdict(int, {}),
#  'Beloc-Duriles': defaultdict(int, {}),
#  'Beloc Duriles': defaultdict(int, {}),
#  'Lopressor': defaultdict(int, {}),
#  'nadolol': defaultdict(int, {}),
#  'D009248': defaultdict(int, {}),
#  'Nadolol': defaultdict(int, {}),
#  'SQ-11725': defaultdict(int, {}),
#  'SQ 11725': defaultdict(int, {}),
#  'SQ11725': defaultdict(int, {}),
#  'Corgard': defaultdict(int, {}),
#  'Solgol': defaultdict(int, {}),
#  'propranolol': defaultdict(int, {}),
#  'D011433': defaultdict(int, {}),
#  'Propranolol': defaultdict(int, {}),
#  'Propanolol': defaultdict(int, {}),
#  'Inderal': defaultdict(int, {}),
#  'Avlocardyl': defaultdict(int, {}),
#  'AY-20694': defaultdict(int, {}),
#  'AY 20694': defaultdict(int, {}),
#  'AY20694': defaultdict(int, {}),
#  'Rexigen': defaultdict(int, {}),
#  'Dexpropranolol': defaultdict(int, {}),
#  'Dociton': defaultdict(int, {}),
#  'Obsidan': defaultdict(int, {}),
#  'Obzidan': defaultdict(int, {}),
#  'Propranolol Hydrochloride': defaultdict(int, {}),
#  'Hydrochloride, Propranolol': defaultdict(int, {}),
#  'Anaprilin': defaultdict(int, {}),
#  'Anapriline': defaultdict(int, {}),
#  'Betadren': defaultdict(int, {}),
#  'In cardiology, beta-adrenoceptor antagonists are an important class for the treatment of high blood pressure, arrhythmias and angina pectoris, and for prevention of myocardial infarction.': defaultdict(int,
#              {}),
#  'drug': defaultdict(int, {}),
#  'The fact that drug targeting noradrenergic and/or dopaminergic transmission are still the first-line treatments for many psychiatric disorders (e.g. depression, schizophrenia, and attention deficit hyperactivity disorder) is a testament to the importance of these neurotransmitters and the research that has helped us to understand the regulation of their function.': defaultdict(int,
#              {}),
#  'D065546': defaultdict(int, {}),
#  'Drug Liberation': defaultdict(int, {}),
#  'Liberation, Drug': defaultdict(int, {}),
#  'Drug Release': defaultdict(int, {}),
#  'Release, Drug': defaultdict(int, {}),
#  'Drug Dissolution': defaultdict(int, {}),
#  'Dissolution, Drug': defaultdict(int, {}),
#  'For patients with schizophrenia and persistent aggressive behaviour, clozapine is recommended both for its superior antipsychotic effect and its specific anti-hostility effect.': defaultdict(int,
#              {}),
#  'valproate': defaultdict(int, {}),
#  'Mood stabilizers such as valproate may be helpful in instances of poor impulsivity and personality disorders.': defaultdict(int,
#              {}),
#  'Mood stabilizers': defaultdict(int, {}),
#  'NEW00137': defaultdict(int, {}),
#  'It is possible that these and other compounds with better alpha-2-adrenoceptor selectivity than clonidine may be used in human medicine to ease symptoms of anxiety in drug- and alcohol-related withdrawal syndromes, and as preanaesthetic agents.': defaultdict(int,
#              {}),
#  'β-adrenoceptor antagonists': defaultdict(int, {}),
#  'Whether β-adrenoceptor antagonists potentiate gemcitabine, a standard first-line treatment for advanced pancreatic cancer that offers only modest benefit due to acquired chemoresistance, has not been elucidated.': defaultdict(int,
#              {}),
#  'NE': defaultdict(int, {}),
#  'The present findings provide an insight into possible mechanisms underlying the antiepileptogenic effects of NE in temporal lobe epilepsy, the hyperexcitability and hyper-responsiveness of the amygdala in certain stress-related affective disorders, and the stress-induced exacerbation of seizure activity in epileptic patients.': defaultdict(int,
#              {}),
#  'D050484': defaultdict(int, {}),
#  'norepinephrine': defaultdict(int, {}),
#  'Norepinephrine Plasma Membrane Transport Proteins': defaultdict(int, {}),
#  'Sodium-Dependent Noradrenaline Transporter': defaultdict(int, {}),
#  'Noradrenaline Transporter, Sodium-Dependent': defaultdict(int, {}),
#  'Sodium Dependent Noradrenaline Transporter': defaultdict(int, {}),
#  'Noradrenaline Transporter': defaultdict(int, {}),
#  'Transporter, Noradrenaline': defaultdict(int, {}),
#  'NET Protein, Neuronal': defaultdict(int, {}),
#  'Neuronal NET Protein': defaultdict(int, {}),
#  'Norepinephrine Transporter Protein': defaultdict(int, {}),
#  'Transporter Protein, Norepinephrine': defaultdict(int, {}),
#  'SLC6A2 Protein': defaultdict(int, {}),
#  'Neurotransmitter Transporters, Noradrenaline-Specific': defaultdict(int, {}),
#  'Neurotransmitter Transporters, Noradrenaline Specific': defaultdict(int, {}),
#  'Noradrenaline-Specific Neurotransmitter Transporters': defaultdict(int, {}),
#  'Transporters, Noradrenaline-Specific Neurotransmitter': defaultdict(int, {}),
#  'Norepinephrine Plasma Membrane Transporters': defaultdict(int, {}),
#  'Noradrenaline Plasma Membrane Transport Proteins': defaultdict(int, {}),
#  'Solute Carrier Family 6 Member 2': defaultdict(int, {}),
#  'Norepinephrine Transporter': defaultdict(int, {}),
#  'Transporter, Norepinephrine': defaultdict(int, {}),
#  'Norepinephrine Plasma Membrane Transporter Proteins': defaultdict(int, {}),
#  'benzodiazepines': defaultdict(int, {}),
#  'In addition, benzodiazepines can be effective in some patients, particularly those with associated anxiety.': defaultdict(int,
#              {}),
#  'D001569': defaultdict(int, {}),
#  'Benzodiazepines': defaultdict(int, {}),
#  'Benzodiazepine Compounds': defaultdict(int, {}),
#  'Benzodiazepine': defaultdict(int, {}),
#  '1-octanol': defaultdict(int, {}),
#  'Several new drugs, including 1-octanol, sodium oxybate, dimethoxymethyl-diphenyl-barbituric acid (T-2000) and carisbamate, are currently under investigation for the treatment of essential tremor.': defaultdict(int,
#              {}),
#  'D020003': defaultdict(int, {}),
#  ...}

# %%
# Checkpoint
with open('index_only_entities.pkl', 'rb') as file:
    index = pickle.load(file)

# %%
print("Creating indexes")
with open('../../nfcorpus/raw/doc_dump.txt', 'r') as file:
    reader = csv.reader(file, delimiter='\t')
    entities = list(index.keys())
    for row in tqdm(reader, total=5371):
        row_text = ' '.join(row[2:])
        for entity in entities:
            if entity in row_text:
                index[entity][row[0]] += 1

with open('index_complete.pkl', 'wb') as file:
    pickle.dump(index, file)

index
# Out:
# Creating indexes
# 100%|██████████| 5371/5371 [10:47<00:00,  8.29it/s]
# {'Flibanserin': defaultdict(int, {}),
#  'Type_E1': defaultdict(int, {}),
#  'CHEMICAL': defaultdict(int, {}),
#  'Sentence': defaultdict(int, {}),
#  'Flibanserin, a multifunctional serotonin receptor agonist and antagonist, is currently approved in the United States and Canada for the treatment of acquired, generalized hypoactive sexual desire disorder (HSDD) in premenopausal women.': defaultdict(int,
#              {}),
#  'ID_1': defaultdict(int, {}),
#  'C098107': defaultdict(int, {}),
#  'Full_E1': defaultdict(int, {}),
#  'MeSH_E1': defaultdict(int, {}),
#  'flibanserin [Supplementary Concept]': defaultdict(int, {}),
#  'Synonyms_1': defaultdict(int, {}),
#  'Benzimidazoles': defaultdict(int, {}),
#  'multifunctional serotonin receptor agonist': defaultdict(int, {}),
#  'NEW00001': defaultdict(int, {}),
#  'No synonyms': defaultdict(int, {}),
#  'Obesity': defaultdict(int,
#              {'MED-17': 2,
#               'MED-97': 2,
#               'MED-167': 2,
#               'MED-168': 2,
#               'MED-169': 2,
#               'MED-225': 2,
#               'MED-313': 2,
#               'MED-532': 2,
#               'MED-590': 2,
#               'MED-681': 2,
#               'MED-794': 1,
#               'MED-816': 1,
#               'MED-1056': 1,
#               'MED-1074': 1,
#               'MED-1075': 1,
#               'MED-1133': 1,
#               'MED-1228': 1,
#               'MED-1235': 1,
#               'MED-1298': 1,
#               'MED-1304': 1,
#               'MED-1309': 1,
#               'MED-1334': 1,
#               'MED-1457': 1,
#               'MED-1468': 1,
#               'MED-1471': 1,
#               'MED-1506': 1,
#               'MED-1514': 1,
#               'MED-1518': 1,
#               'MED-1632': 1,
#               'MED-1665': 1,
#               'MED-1672': 1,
#               'MED-1716': 1,
#               'MED-1718': 1,
#               'MED-1790': 1,
#               'MED-1796': 1,
#               'MED-1800': 1,
#               'MED-1803': 1,
#               'MED-1868': 1,
#               'MED-1964': 1,
#               'MED-1996': 1,
#               'MED-2126': 1,
#               'MED-2154': 1,
#               'MED-2379': 1,
#               'MED-2437': 1,
#               'MED-2586': 1,
#               'MED-2715': 1,
#               'MED-2716': 1,
#               'MED-2718': 1,
#               'MED-2722': 1,
#               'MED-2805': 1,
#               'MED-3039': 1,
#               'MED-3052': 1,
#               'MED-3470': 1,
#               'MED-3481': 1,
#               'MED-3596': 1,
#               'MED-3698': 1,
#               'MED-3866': 1,
#               'MED-4202': 1,
#               'MED-4251': 1,
#               'MED-4260': 1,
#               'MED-4261': 1,
#               'MED-4264': 1,
#               'MED-4277': 1,
#               'MED-4341': 1,
#               'MED-4732': 1,
#               'MED-4764': 1,
#               'MED-4776': 1,
#               'MED-5286': 1,
#               'MED-5317': 1,
#               'MED-5323': 1,
#               'MED-5324': 1}),
#  'DISEASE': defaultdict(int, {'MED-4923': 1, 'MED-4925': 1}),
#  'Obesity is associated with reduced testosterone and worsened erectile and sexual function in men.': defaultdict(int,
#              {}),
#  'D063766': defaultdict(int, {}),
#  'Pediatric Obesity': defaultdict(int, {}),
#  'Obesity, Pediatric': defaultdict(int, {}),
#  'Obesity in Childhood': defaultdict(int, {}),
#  'Childhood Onset Obesity': defaultdict(int, {}),
#  'Obesity, Childhood Onset': defaultdict(int, {}),
#  'Child Obesity': defaultdict(int, {}),
#  'Obesity, Child': defaultdict(int, {}),
#  'Childhood Obesity': defaultdict(int,
#              {'MED-1228': 1, 'MED-1790': 1, 'MED-2126': 1}),
#  'Obesity, Childhood': defaultdict(int, {}),
#  'Adolescent Obesity': defaultdict(int, {}),
#  'Obesity, Adolescent': defaultdict(int, {}),
#  'Obesity in Adolescence': defaultdict(int, {}),
#  'Infantile Obesity': defaultdict(int, {}),
#  'Obesity, Infantile': defaultdict(int, {}),
#  'Infant Obesity': defaultdict(int, {}),
#  'Obesity, Infant': defaultdict(int, {}),
#  'Childhood Overweight': defaultdict(int, {}),
#  'Overweight, Childhood': defaultdict(int, {}),
#  'Infant Overweight': defaultdict(int, {}),
#  'Overweight, Infant': defaultdict(int, {}),
#  'Adolescent Overweight': defaultdict(int, {}),
#  'Overweight, Adolescent': defaultdict(int, {}),
#  'montelukast': defaultdict(int, {}),
#  'Although montelukast is considered to be a safe drug, there are concerns regarding adverse drug reactions, including the rare occurrence of Churg-Strauss syndrome and, despite insufficient data, the possibility of neuropsychiatric events such as anxiety, depression, sleep disturbance, and suicidality.': defaultdict(int,
#              {}),
#  'C093875': defaultdict(int, {}),
#  'montelukast [Supplementary Concept]': defaultdict(int, {}),
#  'Acetates': defaultdict(int, {}),
#  'Cyclopropanes': defaultdict(int, {}),
#  'Quinolines': defaultdict(int, {}),
#  'Sulfides': defaultdict(int, {}),
#  'omega-3 fatty acids': defaultdict(int,
#              {'MED-29': 2,
#               'MED-190': 2,
#               'MED-304': 2,
#               'MED-485': 2,
#               'MED-497': 2,
#               'MED-502': 2,
#               'MED-598': 2,
#               'MED-601': 2,
#               'MED-686': 2,
#               'MED-839': 1,
#               'MED-928': 1,
#               'MED-1093': 1,
#               'MED-1397': 1,
#               'MED-1505': 1,
#               'MED-1576': 1,
#               'MED-2452': 1,
#               'MED-2754': 1,
#               'MED-2756': 1,
#               'MED-2916': 1,
#               'MED-3014': 1,
#               'MED-3030': 1,
#               'MED-3389': 1,
#               'MED-3405': 1,
#               'MED-3427': 1,
#               'MED-3586': 1,
#               'MED-3597': 1,
#               'MED-3879': 1,
#               'MED-4108': 1,
#               'MED-4204': 1,
#               'MED-4233': 1,
#               'MED-4299': 1,
#               'MED-4626': 1,
#               'MED-4633': 1,
#               'MED-4718': 1,
#               'MED-4943': 1,
#               'MED-4944': 1,
#               'MED-5262': 1,
#               'MED-5299': 1,
#               'MED-5342': 1,
#               'MED-5370': 1,
#               'MED-5371': 1}),
#  'NUTRITION': defaultdict(int, {}),
#  'Since omega-3 fatty acids like EPA are precursors for the biosynthesis of eicosanoids including leukotrienes, a common factor to these psychiatric adverse events may be perturbations in this highly complex system of lipid inflammatory mediators.': defaultdict(int,
#              {}),
#  'D015525': defaultdict(int, {}),
#  'Fatty Acids, Omega-3': defaultdict(int, {}),
#  'Omega-3 Fatty Acid': defaultdict(int,
#              {'MED-814': 1, 'MED-2403': 1, 'MED-2411': 1, 'MED-5371': 1}),
#  'Acid, Omega-3 Fatty': defaultdict(int, {}),
#  'Fatty Acid, Omega-3': defaultdict(int, {}),
#  'Omega 3 Fatty Acid': defaultdict(int, {}),
#  'Omega-3 Fatty Acids': defaultdict(int,
#              {'MED-814': 1, 'MED-2403': 1, 'MED-2411': 1, 'MED-5371': 1}),
#  'n-3 Oil': defaultdict(int, {}),
#  'Oil, n-3': defaultdict(int, {}),
#  'n 3 Oil': defaultdict(int, {}),
#  'n3 Oil': defaultdict(int, {}),
#  'Oil, n3': defaultdict(int, {}),
#  'n-3 Fatty Acids': defaultdict(int,
#              {'MED-256': 2,
#               'MED-2401': 1,
#               'MED-2408': 1,
#               'MED-2912': 1,
#               'MED-3010': 1,
#               'MED-3028': 1}),
#  'n 3 Fatty Acids': defaultdict(int, {}),
#  'Omega 3 Fatty Acids': defaultdict(int, {}),
#  'n-3 PUFA': defaultdict(int,
#              {'MED-814': 1,
#               'MED-1528': 1,
#               'MED-2398': 1,
#               'MED-2403': 1,
#               'MED-2406': 1,
#               'MED-2409': 1,
#               'MED-2411': 1,
#               'MED-4345': 1,
#               'MED-4628': 1,
#               'MED-4731': 1,
#               'MED-4734': 1,
#               'MED-4736': 1,
#               'MED-5098': 1,
#               'MED-5102': 1,
#               'MED-5368': 1}),
#  'PUFA, n-3': defaultdict(int, {}),
#  'n 3 PUFA': defaultdict(int, {}),
#  'n3 Fatty Acid': defaultdict(int, {}),
#  'Fatty Acid, n3': defaultdict(int, {}),
#  'n3 PUFA': defaultdict(int, {}),
#  'PUFA, n3': defaultdict(int, {}),
#  'n3 Polyunsaturated Fatty Acid': defaultdict(int, {}),
#  'n3 Oils': defaultdict(int, {}),
#  'n-3 Oils': defaultdict(int, {}),
#  'n 3 Oils': defaultdict(int, {}),
#  'N-3 Fatty Acid': defaultdict(int, {}),
#  'Acid, N-3 Fatty': defaultdict(int, {}),
#  'Fatty Acid, N-3': defaultdict(int, {}),
#  'N 3 Fatty Acid': defaultdict(int, {}),
#  'n-3 Polyunsaturated Fatty Acid': defaultdict(int, {}),
#  'n 3 Polyunsaturated Fatty Acid': defaultdict(int, {}),
#  'EPA': defaultdict(int,
#              {'MED-44': 2,
#               'MED-121': 2,
#               'MED-188': 2,
#               'MED-262': 2,
#               'MED-304': 2,
#               'MED-309': 2,
#               'MED-483': 2,
#               'MED-577': 2,
#               'MED-814': 1,
#               'MED-839': 1,
#               'MED-871': 1,
#               'MED-927': 1,
#               'MED-928': 1,
#               'MED-956': 1,
#               'MED-1093': 1,
#               'MED-1146': 1,
#               'MED-1599': 1,
#               'MED-1730': 1,
#               'MED-1734': 1,
#               'MED-1738': 1,
#               'MED-1958': 1,
#               'MED-2403': 1,
#               'MED-2411': 1,
#               'MED-2477': 1,
#               'MED-2634': 1,
#               'MED-2655': 1,
#               'MED-2751': 1,
#               'MED-2916': 1,
#               'MED-2919': 1,
#               'MED-3014': 1,
#               'MED-3017': 1,
#               'MED-3030': 1,
#               'MED-3031': 1,
#               'MED-3034': 1,
#               'MED-3385': 1,
#               'MED-3545': 1,
#               'MED-3868': 1,
#               'MED-3995': 1,
#               'MED-4005': 1,
#               'MED-4375': 1,
#               'MED-4626': 1,
#               'MED-4633': 1,
#               'MED-4718': 1,
#               'MED-4734': 1,
#               'MED-4736': 1,
#               'MED-4949': 1,
#               'MED-5077': 1,
#               'MED-5095': 1,
#               'MED-5096': 1,
#               'MED-5342': 1,
#               'MED-5361': 1,
#               'MED-5364': 1,
#               'MED-5371': 1}),
#  'D015118': defaultdict(int, {}),
#  'eicosapentaenoic acid': defaultdict(int,
#              {'MED-125': 2,
#               'MED-132': 2,
#               'MED-190': 2,
#               'MED-577': 2,
#               'MED-814': 1,
#               'MED-927': 1,
#               'MED-1093': 1,
#               'MED-2403': 1,
#               'MED-2411': 1,
#               'MED-2462': 1,
#               'MED-2470': 1,
#               'MED-2620': 1,
#               'MED-2628': 1,
#               'MED-2642': 1,
#               'MED-2649': 1,
#               'MED-2754': 1,
#               'MED-3545': 1,
#               'MED-3868': 1,
#               'MED-4302': 1,
#               'MED-4549': 1,
#               'MED-4550': 1,
#               'MED-4551': 1,
#               'MED-4626': 1,
#               'MED-4631': 1,
#               'MED-4633': 1,
#               'MED-4718': 1,
#               'MED-5095': 1,
#               'MED-5096': 1,
#               'MED-5342': 1,
#               'MED-5361': 1,
#               'MED-5371': 1}),
#  'Eicosapentaenoic Acid': defaultdict(int, {}),
#  '5,8,11,14,17-Eicosapentaenoic Acid': defaultdict(int, {}),
#  'Eicosapentanoic Acid': defaultdict(int, {}),
#  'Acid, Eicosapentanoic': defaultdict(int, {}),
#  'omega-3-Eicosapentaenoic Acid': defaultdict(int, {}),
#  'omega 3 Eicosapentaenoic Acid': defaultdict(int, {}),
#  'Timnodonic Acid': defaultdict(int, {}),
#  'Icosapent': defaultdict(int, {}),
#  '5,8,11,14,17-Icosapentaenoic Acid': defaultdict(int, {}),
#  'Results Previous use of montelukast correlated with improved scores on cognitive or neurological functioning (F\u2009=\u20092.20, p\u2009=\u20090.03 in a multivariate test).': defaultdict(int,
#              {}),
#  'Ascorbic acid': defaultdict(int,
#              {'MED-1198': 1, 'MED-1846': 1, 'MED-2983': 1}),
#  'BIOCHEMICAL': defaultdict(int, {}),
#  "Ascorbic acid has emerged as a neuroprotective compound against neurotoxicants and neurodegenerative diseases, including Alzheimer's disease, multiple sclerosis and amyotrophic lateral sclerosis.": defaultdict(int,
#              {}),
#  'D001206': defaultdict(int, {}),
#  'Ascorbic Acid Deficiency': defaultdict(int, {}),
#  'Vitamin C Deficiency': defaultdict(int, {}),
#  'Deficiency, Vitamin C': defaultdict(int, {}),
#  'Deficiencies, Vitamin C': defaultdict(int, {}),
#  'Vitamin C Deficiencies': defaultdict(int, {}),
#  'Deficiency, Ascorbic Acid': defaultdict(int, {}),
#  'Ascorbic Acid Deficiencies': defaultdict(int, {}),
#  'Deficiencies, Ascorbic Acid': defaultdict(int, {}),
#  'schizophrenic patients': defaultdict(int, {}),
#  'We previously reported that a certain subtype of schizophrenic patients exhibit idiopathic carbonyl stress with high plasma pentosidine levels and the depletion of vitamin B6, without underlying diabetes or chronic kidney disease, the two major causes of elevated AGEs.': defaultdict(int,
#              {}),
#  'NEW00007': defaultdict(int, {}),
#  'In particular, the markedly lowered vitamin B6 levels in schizophrenic patients with high pentosidine levels suggest that pyridoxamine may prove to be clinically useful.': defaultdict(int,
#              {}),
#  'lowered vitamin B6 levels': defaultdict(int, {}),
#  'NEW00011': defaultdict(int, {}),
#  'hemorrhagic disease': defaultdict(int, {}),
#  'Intramuscular administration of vitamin K for prophylaxis against hemorrhagic disease of the newborn has the disadvantage of increased cost, pain, anxiety to parents and risk of transmission of infection.': defaultdict(int,
#              {}),
#  'D018164': defaultdict(int, {}),
#  'Hemorrhagic Disease Virus, Epizootic': defaultdict(int, {}),
#  'Epizootic hemorrhagic disease virus': defaultdict(int, {}),
#  'vitamin K': defaultdict(int, {'MED-4724': 1, 'MED-4872': 1}),
#  'D064417': defaultdict(int, {}),
#  'Vitamin K Epoxide Reductases': defaultdict(int, {}),
#  'Vitamin K Epoxidase': defaultdict(int, {}),
#  'Epoxidase, Vitamin K': defaultdict(int, {}),
#  'K Epoxidase, Vitamin': defaultdict(int, {}),
#  'Phylloquinone Epoxide Reductase': defaultdict(int, {}),
#  'Epoxide Reductase, Phylloquinone': defaultdict(int, {}),
#  'Reductase, Phylloquinone Epoxide': defaultdict(int, {}),
#  'Vitamin KO Reductase': defaultdict(int, {}),
#  'Reductase, Vitamin KO': defaultdict(int, {}),
#  'Vitamin K 2,3-Epoxide Reductase': defaultdict(int, {}),
#  'Vitamin K 2,3 Epoxide Reductase': defaultdict(int, {}),
#  'Vitamin K Epoxide Reductase': defaultdict(int, {}),
#  'Vitamin K1 Oxide Reductase': defaultdict(int, {}),
#  'Menadione Epoxide Reductase': defaultdict(int, {}),
#  'Epoxide Reductase, Menadione': defaultdict(int, {}),
#  'Reductase, Menadione Epoxide': defaultdict(int, {}),
#  'Vitamin K 1 Epoxidase': defaultdict(int, {}),
#  'Riboflavin transporter deficiency': defaultdict(int, {}),
#  'Riboflavin transporter deficiency 2 (RTD2) is a rare neurological disorder caused by mutations in the Solute carrier family 52 member 2 (Slc52a2) gene encoding human riboflavin transporter 2 (RFVT2).': defaultdict(int,
#              {}),
#  'NEW00013': defaultdict(int, {}),
#  'folate deficiency': defaultdict(int, {'MED-993': 1}),
#  'Several studies demonstrate a clinical correlation between folate deficiency and psychiatric hospitalization.': defaultdict(int,
#              {}),
#  'NEW00014': defaultdict(int, {}),
#  'psychiatric hospitalization': defaultdict(int, {}),
#  'NEW00015': defaultdict(int, {}),
#  'psychiatric patients': defaultdict(int, {}),
#  'These observations agree that psychiatric patients are more likely to have low serum folate values, and suggest that poor diet does not explain the increased likelihood.': defaultdict(int,
#              {}),
#  'NEW00016': defaultdict(int, {}),
#  'B12 insufficiency': defaultdict(int, {}),
#  'Although our study does not show that B12 insufficiency is a direct risk factor to cognitive decline, B12 levels could be a contributing factor to cognitive function.': defaultdict(int,
#              {}),
#  'NEW00018': defaultdict(int, {}),
#  'Biotin-dependent carboxylases': defaultdict(int, {}),
#  'Biotin-dependent carboxylases catalyze the fixation of bicarbonate in organic acids and play crucial roles in the metabolism of fatty acids, amino acids and glucose.': defaultdict(int,
#              {}),
#  'NEW00019': defaultdict(int, {}),
#  'biotin deficiency': defaultdict(int, {}),
#  'Symptoms of biotin deficiency include seizures, hypotonia, ataxia, dermatitis, hair loss, mental retardation, ketolactic acidosis, organic aciduria and also fetal malformations.': defaultdict(int,
#              {}),
#  'C531633': defaultdict(int, {}),
#  'Biotin deficiency [Supplementary Concept]': defaultdict(int, {}),
#  'Biotinidase Deficiency': defaultdict(int, {}),
#  'folate levels': defaultdict(int,
#              {'MED-990': 1, 'MED-1201': 1, 'MED-4288': 1, 'MED-5002': 1}),
#  'Meta-analyses showed significantly lower vitamin B12 levels in ASD and ADHD patients vs. healthy controls (HC), while folate levels were higher in ADHD patients vs. HC.': defaultdict(int,
#              {}),
#  'NEW00022': defaultdict(int, {}),
#  'vitamin abnormalities': defaultdict(int, {}),
#  'There was significant heterogeneity between the studies, however many found different types of vitamin abnormalities in CAD with psychiatric disorders.': defaultdict(int,
#              {}),
#  'NEW00024': defaultdict(int, {}),
#  'AD VaD patients': defaultdict(int, {}),
#  'AD and VaD patients showed similar plasma levels of plasma antioxidants and MDA as well as a similar IgG content of protein carbonyls and dityrosine.': defaultdict(int,
#              {}),
#  'NEW00025': defaultdict(int, {}),
#  'serotonin 5-HT1A/1B receptor agonist eltoprazine': defaultdict(int, {}),
#  "The serotonin 5-HT1A/1B receptor agonist eltoprazine suppressed dyskinetic-like behavior in animal models of Parkinson's disease (PD) but simultaneously reduced levodopa (l-dopa)-induced motility.": defaultdict(int,
#              {}),
#  'NEW00026': defaultdict(int, {}),
#  'adenosine A2A receptor antagonists': defaultdict(int, {}),
#  'Moreover, adenosine A2A receptor antagonists, such as preladenant, significantly increased l-dopa efficacy in PD without exacerbating dyskinetic-like behavior.': defaultdict(int,
#              {}),
#  'D058917': defaultdict(int, {}),
#  'Adenosine A2 Receptor Antagonists': defaultdict(int, {}),
#  'Adenosine A2B Receptor Antagonists': defaultdict(int, {}),
#  'Adenosine A2A Receptor Antagonists': defaultdict(int, {}),
#  'preladenant': defaultdict(int, {}),
#  'C539997': defaultdict(int, {}),
#  '2-(2-furanyl)-7-(2-(4-(4-(2-methoxyethoxy)phenyl)-1-piperazinyl)ethyl)-7H-pyrazolo(4,3-e)(1,2,4)triazolo(1,5-c)pyrimidine-5-amine [Supplementary Concept]': defaultdict(int,
#              {}),
#  'Pyrimidines': defaultdict(int, {}),
#  'Triazoles': defaultdict(int, {}),
#  'CSC': defaultdict(int,
#              {'MED-142': 2, 'MED-2232': 1, 'MED-2675': 1, 'MED-2808': 1}),
#  'Acute administration of the adenosine A2A receptor antagonists CSC or MSX-3 at the highest doses tested (5 and 1.25mg/kg, respectively) significantly reduces haloperidol-induced catalepsy.': defaultdict(int,
#              {}),
#  'NEW00030': defaultdict(int, {}),
#  'chronic subordinate colony housing': defaultdict(int, {}),
#  'ACPT-I': defaultdict(int, {}),
#  'Furthermore, the acute co-administration of ACPT-I 1mg/kg, but not 5mg/kg, with CSC markedly reduces catalepsy.': defaultdict(int,
#              {}),
#  'C108242': defaultdict(int, {}),
#  '1-aminocyclopentane-1,3,4-tricarboxylic acid [Supplementary Concept]': defaultdict(int,
#              {}),
#  'Cyclopentanes': defaultdict(int, {}),
#  'Tricarboxylic Acids': defaultdict(int, {}),
#  'MPEP': defaultdict(int, {}),
#  'After a 3-week treatment, however, the combination of CSC and MPEP was found to reduce haloperidol-induced catalepsy.': defaultdict(int,
#              {}),
#  'NEW00032': defaultdict(int, {}),
#  'mGluR5 inverse agonist 2-methyl-6-(phenylethynyl)pyridine': defaultdict(int,
#              {}),
#  'Altogether, these results show for the first time that systemic activation of group III mGlu receptors with ACPT-I provides benefits in parkinsonian rats and underlie a possible interaction with A2A receptors to regulate basal ganglia motor function.': defaultdict(int,
#              {}),
#  'L-3,4-dihydroxyphenylalanine': defaultdict(int, {}),
#  "Long-term therapy with L-3,4-dihydroxyphenylalanine (L-DOPA), still the most effective treatment in Parkinson's disease (PD), is associated with severe motor complications such as dyskinesia.": defaultdict(int,
#              {}),
#  'D007980': defaultdict(int, {}),
#  'Levodopa': defaultdict(int, {}),
#  'L-Dopa': defaultdict(int, {}),
#  'L Dopa': defaultdict(int, {}),
#  '3-Hydroxy-L-tyrosine': defaultdict(int, {}),
#  '3 Hydroxy L tyrosine': defaultdict(int, {}),
#  'L-3,4-Dihydroxyphenylalanine': defaultdict(int, {}),
#  'L 3,4 Dihydroxyphenylalanine': defaultdict(int, {}),
#  'Levopa': defaultdict(int, {}),
#  'Larodopa': defaultdict(int, {}),
#  'Dopaflex': defaultdict(int, {}),
#  'Dopar': defaultdict(int, {}),
#  "Parkinson's disease": defaultdict(int,
#              {'MED-1086': 1,
#               'MED-1270': 1,
#               'MED-1282': 1,
#               'MED-1408': 1,
#               'MED-1499': 1,
#               'MED-1629': 1,
#               'MED-1730': 1,
#               'MED-2164': 1,
#               'MED-2165': 1,
#               'MED-2173': 1,
#               'MED-2176': 1,
#               'MED-2979': 1,
#               'MED-3925': 1,
#               'MED-3928': 1,
#               'MED-3930': 1,
#               'MED-3931': 1,
#               'MED-3933': 1,
#               'MED-4478': 1,
#               'MED-4488': 1,
#               'MED-4926': 1,
#               'MED-4939': 1,
#               'MED-5054': 1,
#               'MED-5335': 1}),
#  'D010300': defaultdict(int, {}),
#  'Parkinson Disease': defaultdict(int, {'MED-3936': 1}),
#  "Idiopathic Parkinson's Disease": defaultdict(int, {}),
#  "Lewy Body Parkinson's Disease": defaultdict(int, {}),
#  "Parkinson's Disease, Idiopathic": defaultdict(int, {}),
#  "Parkinson's Disease, Lewy Body": defaultdict(int, {}),
#  'Parkinson Disease, Idiopathic': defaultdict(int, {}),
#  "Parkinson's Disease": defaultdict(int, {'MED-3927': 1, 'MED-3931': 1}),
#  'Idiopathic Parkinson Disease': defaultdict(int, {}),
#  'Lewy Body Parkinson Disease': defaultdict(int, {}),
#  'Primary Parkinsonism': defaultdict(int, {}),
#  'Parkinsonism, Primary': defaultdict(int, {}),
#  'Paralysis Agitans': defaultdict(int, {}),
#  'L-DOPA': defaultdict(int, {}),
#  'NEW00034': defaultdict(int, {}),
#  'dopamine precursor L-3,4-dihydroxyphenylalanine': defaultdict(int, {}),
#  'KW-6002': defaultdict(int, {}),
#  'Istradefylline (KW-6002) is the first of several adenosine A2A receptor antagonists in development for PD to advance to phase III clinical trials.': defaultdict(int,
#              {}),
#  'C111599': defaultdict(int, {}),
#  'Istradefylline': defaultdict(int, {}),
#  'istradefylline [Supplementary Concept]': defaultdict(int, {}),
#  'Purines': defaultdict(int, {}),
#  'caffeine': defaultdict(int,
#              {'MED-401': 2,
#               'MED-545': 2,
#               'MED-597': 2,
#               'MED-672': 2,
#               'MED-870': 1,
#               'MED-878': 1,
#               'MED-879': 1,
#               'MED-880': 1,
#               'MED-881': 1,
#               'MED-882': 1,
#               'MED-883': 1,
#               'MED-992': 1,
#               'MED-1620': 1,
#               'MED-1622': 1,
#               'MED-1631': 1,
#               'MED-1637': 1,
#               'MED-1638': 1,
#               'MED-1639': 1,
#               'MED-1640': 1,
#               'MED-1641': 1,
#               'MED-1642': 1,
#               'MED-1645': 1,
#               'MED-1647': 1,
#               'MED-1648': 1,
#               'MED-2155': 1,
#               'MED-2167': 1,
#               'MED-2219': 1,
#               'MED-2253': 1,
#               'MED-3202': 1,
#               'MED-3489': 1,
#               'MED-3585': 1,
#               'MED-3588': 1,
#               'MED-3800': 1,
#               'MED-3816': 1,
#               'MED-3927': 1,
#               'MED-3930': 1,
#               'MED-3932': 1,
#               'MED-4018': 1,
#               'MED-4034': 1,
#               'MED-4040': 1,
#               'MED-4197': 1,
#               'MED-4331': 1,
#               'MED-4377': 1,
#               'MED-4438': 1,
#               'MED-4439': 1,
#               'MED-4699': 1,
#               'MED-4774': 1,
#               'MED-4776': 1,
#               'MED-4865': 1,
#               'MED-5048': 1,
#               'MED-5156': 1,
#               'MED-5242': 1,
#               'MED-5243': 1,
#               'MED-5244': 1,
#               'MED-5245': 1,
#               'MED-5246': 1,
#               'MED-5247': 1,
#               'MED-5248': 1,
#               'MED-5249': 1,
#               'MED-5252': 1,
#               'MED-5254': 1,
#               'MED-5255': 1,
#               'MED-5256': 1,
#               'MED-5305': 1}),
#  'Lastly, epidemiological evidence indicates that regular human consumption of caffeine, the most widely used psychoactive drug and nonselective AR antagonists, is associated with the reduced cognitive decline in aging and AD patients, and with the reduced risk in developing PD.': defaultdict(int,
#              {}),
#  'D002110': defaultdict(int, {}),
#  'Caffeine': defaultdict(int,
#              {'MED-672': 2,
#               'MED-880': 1,
#               'MED-956': 1,
#               'MED-1631': 1,
#               'MED-1638': 1,
#               'MED-1641': 1,
#               'MED-2167': 1,
#               'MED-3816': 1,
#               'MED-3927': 1,
#               'MED-3932': 1,
#               'MED-4438': 1,
#               'MED-4439': 1,
#               'MED-4774': 1,
#               'MED-5242': 1,
#               'MED-5245': 1,
#               'MED-5246': 1,
#               'MED-5247': 1,
#               'MED-5248': 1,
#               'MED-5249': 1,
#               'MED-5251': 1,
#               'MED-5252': 1,
#               'MED-5254': 1,
#               'MED-5255': 1}),
#  '1,3,7-Trimethylxanthine': defaultdict(int, {}),
#  'Vivarin': defaultdict(int, {}),
#  'Caffedrine': defaultdict(int, {}),
#  'Coffeinum N': defaultdict(int, {}),
#  'Percutaféine': defaultdict(int, {}),
#  'Dexitac': defaultdict(int, {}),
#  'Durvitan': defaultdict(int, {}),
#  'No Doz': defaultdict(int, {}),
#  'Percoffedrinol N': defaultdict(int, {}),
#  'Quick-Pep': defaultdict(int, {}),
#  'Quick Pep': defaultdict(int, {}),
#  'QuickPep': defaultdict(int, {}),
#  'Coffeinum Purrum': defaultdict(int, {}),
#  'psychoactive drug': defaultdict(int, {}),
#  'D011619': defaultdict(int, {}),
#  'Psychotropic Drugs': defaultdict(int, {}),
#  'Drugs, Psychotropic': defaultdict(int, {}),
#  'Psychoactive Agent': defaultdict(int, {}),
#  'Agent, Psychoactive': defaultdict(int, {}),
#  'Psychoactive Drug': defaultdict(int, {}),
#  'Drug, Psychoactive': defaultdict(int, {}),
#  'Psychopharmaceuticals': defaultdict(int, {}),
#  'Psychoactive Agents': defaultdict(int, {}),
#  'Agents, Psychoactive': defaultdict(int, {}),
#  'Psychoactive Drugs': defaultdict(int, {}),
#  'Drugs, Psychoactive': defaultdict(int, {}),
#  'Psychotropic Drug': defaultdict(int, {}),
#  'Drug, Psychotropic': defaultdict(int, {}),
#  'Psychopharmaceutical': defaultdict(int, {}),
#  'Adenosine A2A receptor antagonists': defaultdict(int, {}),
#  "Adenosine A2A receptor antagonists represent a new way forward in the symptomatic treatment of Parkinson's disease (PD) through a non-dopaminergic mechanism.": defaultdict(int,
#              {}),
#  'adenosine A2A antagonists': defaultdict(int, {}),
#  'As a class, adenosine A2A antagonists are effective in reversing motor deficits in haloperidol-treated rodents, 6-OHDA-lesioned rats, and MPTP-treated primates when combined with low doses of l-dopa or dopamine agonist drugs.': defaultdict(int,
#              {}),
#  'NEW00035': defaultdict(int, {}),
#  'Adenosine A2A receptor antagonists are active in animal models of reduced cognition, anxiety, and depression and so this drug class may also be effective in controlling the neuropsychiatric components of nonmotor symptoms in PD.': defaultdict(int,
#              {}),
#  'A2A antagonists': defaultdict(int, {}),
#  'Preclinical evidence has shown that A2A antagonists can prevent neuronal loss in experimental models of PD and their disease modifying activity needs to be explored in man.': defaultdict(int,
#              {}),
#  'NEW00039': defaultdict(int, {}),
#  'rimonabant': defaultdict(int, {}),
#  'These results suggest that rimonabant can prevent the relapse to alcohol, even when an interaction with nicotine exists-the most frequent situation in human alcohol abuse.': defaultdict(int,
#              {}),
#  'D000077285': defaultdict(int, {}),
#  'Rimonabant': defaultdict(int, {}),
#  'SR141716': defaultdict(int, {}),
#  'SR 141716': defaultdict(int, {}),
#  'Rimonabant Hydrochloride': defaultdict(int, {}),
#  'N-(Piperidin-1-yl)-5-(4-chlorophenyl)-1-(2,4-dichlorophenyl)-4-methyl-1H-pyrazole-3-carboxamide hydrochloride': defaultdict(int,
#              {}),
#  'Zimulti': defaultdict(int, {}),
#  'SR 141716A': defaultdict(int, {}),
#  'SR-141716A': defaultdict(int, {}),
#  'SR141716A': defaultdict(int, {}),
#  'Acomplia': defaultdict(int, {}),
#  'acid/kainate receptor-type neurotoxicity': defaultdict(int, {}),
#  'N-methyl-D-aspartate receptor-induced toxicity has been shown to be calcium dependent; this study demonstrates that 2-amino-3-(4-butyl-3-hydroxyisoxazol-5-yl)propionic acid/kainate receptor-type neurotoxicity is also calcium-dependent, partly mediated by voltage sensitive calcium channels.': defaultdict(int,
#              {}),
#  'NEW00041': defaultdict(int, {}),
#  'oxotremorine treatment': defaultdict(int, {}),
#  'In this study, we have evaluated the effect of oxotremorine treatment on chronic restraint stress-induced cognitive deficits.': defaultdict(int,
#              {}),
#  'NEW00043': defaultdict(int, {}),
#  'tramadol administration': defaultdict(int, {}),
#  'Overall, the outcomes of this study suggest that tramadol administration has a neurodegeneration effect on the cerebellar cortex via several pathways consisting of microgliosis, apoptosis, necroptosis, and neuroinflammatoin.': defaultdict(int,
#              {}),
#  'NEW00045': defaultdict(int, {}),
#  'clozapine': defaultdict(int, {}),
#  'Concerns about intentional and unintentional poisoning present a barrier to wider use of clozapine in treatment-resistant schizophrenia.': defaultdict(int,
#              {}),
#  'D003024': defaultdict(int, {}),
#  'Clozapine': defaultdict(int, {}),
#  'Clozaril': defaultdict(int, {}),
#  'Leponex': defaultdict(int, {}),
#  'AOP': defaultdict(int, {'MED-3914': 1, 'MED-3921': 1}),
#  'AOP correlated in CNCP OST patients with: age ≤ 40 years old, female gender, low-income status, methadone-maintained treatment, mental health disorder, hepatitis C virus (HCV) infection, and alcohol abuse disorder.': defaultdict(int,
#              {}),
#  'NEW00047': defaultdict(int, {}),
#  'analgesic opioid prescription': defaultdict(int, {}),
#  'nefopam': defaultdict(int, {}),
#  'A 5 mg/kg dose of nefopam significantly elevated the electric seizure threshold, while a dose of 1 mg/kg failed to protect mice against electroconvulsion.': defaultdict(int,
#              {}),
#  'D009340': defaultdict(int, {}),
#  'Nefopam': defaultdict(int, {}),
#  'Nefopam Hydrochloride': defaultdict(int, {}),
#  'Hydrochloride, Nefopam': defaultdict(int, {}),
#  'Fenazoxine': defaultdict(int, {}),
#  'Acupan': defaultdict(int, {}),
#  'Ajan': defaultdict(int, {}),
#  'Silentan Nefopam': defaultdict(int, {}),
#  'Nefopam, Silentan': defaultdict(int, {}),
#  'Oxycodone': defaultdict(int, {}),
#  'Oxycodone is administered to opioid-naive patients with severe pain and to patients who were unsuccessfully treated with weak opioids, namely tramadol, codeine and dihydrocodeine.': defaultdict(int,
#              {}),
#  'D010098': defaultdict(int, {}),
#  'Dihydrone': defaultdict(int, {}),
#  'Oxycone': defaultdict(int, {}),
#  'Dihydrohydroxycodeinone': defaultdict(int, {}),
#  'Oxycodeinon': defaultdict(int, {}),
#  'Eucodal': defaultdict(int, {}),
#  'Theocodin': defaultdict(int, {}),
#  'Oxycodone Hydrochloride': defaultdict(int, {}),
#  'Oxycontin': defaultdict(int, {}),
#  'Pancodine': defaultdict(int, {}),
#  'Dinarkon': defaultdict(int, {}),
#  'Oxiconum': defaultdict(int, {}),
#  'morphine': defaultdict(int,
#              {'MED-214': 2,
#               'MED-361': 2,
#               'MED-362': 2,
#               'MED-2793': 1,
#               'MED-3144': 1,
#               'MED-3145': 1,
#               'MED-3146': 1,
#               'MED-4526': 1}),
#  'Oxycodone displays high bioavailability after oral administration and may be better than morphine in patients with renal impairment due to the decreased production of active metabolites.': defaultdict(int,
#              {}),
#  'D018847': defaultdict(int, {}),
#  'opioid': defaultdict(int,
#              {'MED-312': 2,
#               'MED-1014': 1,
#               'MED-1242': 1,
#               'MED-3038': 1,
#               'MED-3043': 1,
#               'MED-3056': 1,
#               'MED-4400': 1,
#               'MED-4401': 1,
#               'MED-4402': 1,
#               'MED-4525': 1}),
#  'Opioid Peptides': defaultdict(int, {}),
#  'Peptides, Opioid': defaultdict(int, {}),
#  'Opiate Peptides': defaultdict(int, {}),
#  'Peptides, Opiate': defaultdict(int, {}),
#  'Opioid Peptide': defaultdict(int, {}),
#  'Peptide, Opioid': defaultdict(int, {}),
#  'Opiates, Endogenous': defaultdict(int, {}),
#  'Endogenous Opiates': defaultdict(int, {}),
#  'oxycodone': defaultdict(int, {}),
#  'The aim of this review is to outline the pharmacodynamic and pharmacokinetic properties, drug interactions, dosing rules, adverse effects, equianalgesic dose ratio with other opioids and clinical studies of oxycodone in patients with cancer pain.': defaultdict(int,
#              {}),
#  'Nefopam hydrochloride (Acupan) is a potent non-opioid analgesic widely used for the relief of moderate to severe postoperative pain.': defaultdict(int,
#              {}),
#  'Nefopam hydrochloride': defaultdict(int, {}),
#  'When taken in overdose, nefopam has been reported to cause cardiac conduction abnormalities, cerebral oedema, fever and renal failure.': defaultdict(int,
#              {}),
#  'CNS respiratory depression': defaultdict(int, {}),
#  'MENTAL_HEALTH': defaultdict(int, {}),
#               'MED-5256': 1,
#               'MED-5268': 1,
#               'MED-5293': 1,
#               'MED-5296': 1,
#               'MED-5299': 1,
#               'MED-5303': 1,
#               'MED-5305': 1,
#               'MED-5328': 1,
#               'MED-5344': 1,
#               'MED-5360': 1,
#               'MED-5366': 1}),
#  'Patients who had ingested pentazocine with alcohol, a sedative/hypnotic drug, or an antihistamine, showed increased toxicity, including apnea, deep coma, and recurrent seizures.': defaultdict(int,
#              {}),
#  'D064829': defaultdict(int, {}),
#  'Alcohol Abstinence': defaultdict(int, {}),
#  'Abstinence, Alcohol': defaultdict(int, {}),
#  'Abstinence from Ethanol': defaultdict(int, {}),
#  'Abstinence from Ethanols': defaultdict(int, {}),
#  'Ethanol Abstinence': defaultdict(int, {}),
#  'Abstinence, Ethanol': defaultdict(int, {}),
#  'coma inadequate respirations': defaultdict(int, {}),
#  'Three of five patients with coma and inadequate respirations responded to IV naloxone in doses of 0.4 to 1.2 mg.': defaultdict(int,
#              {}),
#  'NEW00060': defaultdict(int, {}),
#  'opioid analgesics': defaultdict(int, {}),
#  'Chronic use (>90 Days) of opioid analgesics significantly increases the risk of development of new depression episodes (NDE).': defaultdict(int,
#              {}),
#  'D018712': defaultdict(int, {}),
#  'Analgesics, Non-Narcotic': defaultdict(int, {}),
#  'Analgesics, Non Narcotic': defaultdict(int, {}),
#  'Non-Narcotic Analgesics': defaultdict(int, {}),
#  'Non-Opioid Analgesic': defaultdict(int, {}),
#  'Analgesic, Non-Opioid': defaultdict(int, {}),
#  'Nonopioid Analgesics': defaultdict(int, {}),
#  'Non-Opioid Analgesics': defaultdict(int, {}),
#  'Analgesics, Non-Opioid': defaultdict(int, {}),
#  'Non Opioid Analgesics': defaultdict(int, {}),
#  'Analgesics, Nonnarcotic': defaultdict(int, {}),
#  'Nonnarcotic Analgesics': defaultdict(int, {}),
#  'Analgesics, Nonopioid': defaultdict(int, {}),
#  'Non Opioid Analgesic': defaultdict(int, {}),
#  'Analgesic, Non Opioid': defaultdict(int, {}),
#  'Opioid Analgesic, Non': defaultdict(int, {}),
#  'Nonopioid Analgesic': defaultdict(int, {}),
#  'Analgesic, Nonopioid': defaultdict(int, {}),
#  'buprenorphine': defaultdict(int, {}),
#  'Two medication treatments (buprenorphine and naltrexone) are effective for treating opioid use disorder (OUD) in office-based settings but are seldom prescribed to adolescents.': defaultdict(int,
#              {}),
#  'D002047': defaultdict(int, {}),
#  'Buprenorphine': defaultdict(int, {}),
#  'Buprenex': defaultdict(int, {}),
#  'Prefin': defaultdict(int, {}),
#  'Subutex': defaultdict(int, {}),
#  'Buprex': defaultdict(int, {}),
#  'Temgesic': defaultdict(int, {}),
#  'Temgésic': defaultdict(int, {}),
#  '6029-M': defaultdict(int, {}),
#  '6029 M': defaultdict(int, {}),
#  '6029M': defaultdict(int, {}),
#  'RX-6029-M': defaultdict(int, {}),
#  'RX 6029 M': defaultdict(int, {}),
#  'RX6029M': defaultdict(int, {}),
#  'Buprenorphine Hydrochloride': defaultdict(int, {}),
#  'Hydrochloride, Buprenorphine': defaultdict(int, {}),
#  'post-traumatic stress disorder': defaultdict(int, {}),
#  'Patients with post-traumatic stress disorder (PTSD) have complex and multiple symptoms, including anxiety, insomnia, and co-occurring pain, often treated with opioids and benzodiazepines.': defaultdict(int,
#              {}),
#  'D013313': defaultdict(int, {}),
#  'Stress Disorders, Post-Traumatic': defaultdict(int, {}),
#  'Post-Traumatic Stress Disorder': defaultdict(int, {}),
#  'Stress Disorder, Post-Traumatic': defaultdict(int, {}),
#  'Neuroses, Post-Traumatic': defaultdict(int, {}),
#  'Neuroses, Post Traumatic': defaultdict(int, {}),
#  'Post-Traumatic Neuroses': defaultdict(int, {}),
#  'PTSD': defaultdict(int, {}),
#  'Neuroses, Posttraumatic': defaultdict(int, {}),
#  'Posttraumatic Neuroses': defaultdict(int, {}),
#  'Post-Traumatic Stress Disorders': defaultdict(int, {}),
#  'Post Traumatic Stress Disorders': defaultdict(int, {}),
#  'Posttraumatic Stress Disorders': defaultdict(int, {}),
#  'Posttraumatic Stress Disorder': defaultdict(int, {}),
#  'Stress Disorder, Posttraumatic': defaultdict(int, {}),
#  'Stress Disorders, Posttraumatic': defaultdict(int, {}),
#  'Post Traumatic Stress Disorder': defaultdict(int, {}),
#  'Stress Disorder, Post Traumatic': defaultdict(int, {}),
#  'Delayed Onset Post-Traumatic Stress Disorder': defaultdict(int, {}),
#  'Delayed Onset Post Traumatic Stress Disorder': defaultdict(int, {}),
#  'Chronic Post-Traumatic Stress Disorder': defaultdict(int, {}),
#  'Chronic Post Traumatic Stress Disorder': defaultdict(int, {}),
#  'Moral Injury': defaultdict(int, {}),
#  'Injury, Moral': defaultdict(int, {}),
#  'Moral Injuries': defaultdict(int, {}),
#  'Acute Post-Traumatic Stress Disorder': defaultdict(int, {}),
#  'Acute Post Traumatic Stress Disorder': defaultdict(int, {}),
#  'chronic stress': defaultdict(int,
#              {'MED-1900': 1,
#               'MED-1908': 1,
#               'MED-1910': 1,
#               'MED-1923': 1,
#               'MED-1931': 1,
#               'MED-1933': 1}),
#  'In this paper, we study whether chronic stress induced by repetition of acute stress protocols affects long-term feeding behavior and growth performance in sea bass and whether exogenous cortisol may induce stress-like changes in these parameters.': defaultdict(int,
#              {}),
#  'NEW00065': defaultdict(int, {}),
#  'antidepressant medications': defaultdict(int,
#              {'MED-1346': 1, 'MED-1348': 1, 'MED-1350': 1, 'MED-1355': 1}),
#  'For example, antidepressant medications may be efficacious in the treatment of depression but only work for so long as they are taken.': defaultdict(int,
#              {}),
#  'NEW00066': defaultdict(int, {}),
#  'sialidase inhibitor oseltamivir': defaultdict(int, {}),
#  'Preclinical reports suggest that the sialidase inhibitor oseltamivir induces a platelet response in the treatment of immune thrombocytopenia.': defaultdict(int,
#              {}),
#  'NEW00067': defaultdict(int, {}),
#  'A. glehni extract': defaultdict(int, {}),
#  'Phytochemical isolation from A. glehni extract yielded three kaempferol glycosides.': defaultdict(int,
#              {}),
#  'NEW00068': defaultdict(int, {}),
#  'phenylpropanoid moieties': defaultdict(int, {}),
#  'The water-ethanol (7:3) extract and both p-coumaric acid and caffeic acid, phenylpropanoid moieties of CQs, had sedative effects in pentobarbital-induced sleeping time in mice and anticonvulsant effects in pentylenetetrazole-induced mice.': defaultdict(int,
#              {}),
#  'NEW00070': defaultdict(int, {}),
#  'water-ethanol extract': defaultdict(int, {}),
#  'NEW00072': defaultdict(int, {}),
#               'MED-5202': 1,
#               'MED-5213': 1,
#               'MED-5222': 1,
#               'MED-5224': 1,
#               'MED-5239': 1,
#               'MED-5290': 1,
#               'MED-5301': 1,
#               'MED-5303': 1,
#               'MED-5311': 1}),
#  'The fact that drug targeting noradrenergic and/or dopaminergic transmission are still the first-line treatments for many psychiatric disorders (e.g. depression, schizophrenia, and attention deficit hyperactivity disorder) is a testament to the importance of these neurotransmitters and the research that has helped us to understand the regulation of their function.': defaultdict(int,
#              {}),
#  'D065546': defaultdict(int, {}),
#  'Drug Liberation': defaultdict(int, {}),
#  'Liberation, Drug': defaultdict(int, {}),
#  'Drug Release': defaultdict(int, {}),
#  'Release, Drug': defaultdict(int, {}),
#  'Drug Dissolution': defaultdict(int, {}),
#  'Dissolution, Drug': defaultdict(int, {}),
#  'For patients with schizophrenia and persistent aggressive behaviour, clozapine is recommended both for its superior antipsychotic effect and its specific anti-hostility effect.': defaultdict(int,
#              {}),
#  'valproate': defaultdict(int, {}),
#  'Mood stabilizers such as valproate may be helpful in instances of poor impulsivity and personality disorders.': defaultdict(int,
#              {}),
#  'Mood stabilizers': defaultdict(int, {}),
#  'NEW00137': defaultdict(int, {}),
#  'It is possible that these and other compounds with better alpha-2-adrenoceptor selectivity than clonidine may be used in human medicine to ease symptoms of anxiety in drug- and alcohol-related withdrawal syndromes, and as preanaesthetic agents.': defaultdict(int,
#              {}),
#  'β-adrenoceptor antagonists': defaultdict(int, {}),
#  'Whether β-adrenoceptor antagonists potentiate gemcitabine, a standard first-line treatment for advanced pancreatic cancer that offers only modest benefit due to acquired chemoresistance, has not been elucidated.': defaultdict(int,
#              {}),
#  'NE': defaultdict(int,
#              {'MED-75': 2,
#               'MED-99': 2,
#               'MED-189': 2,
#               'MED-194': 2,
#               'MED-255': 2,
#               'MED-276': 2,
#               'MED-349': 2,
#               'MED-389': 2,
#               'MED-413': 2,
#               'MED-415': 2,
#               'MED-490': 2,
#               'MED-554': 2,
#               'MED-555': 2,
#               'MED-571': 2,
#               'MED-617': 2,
#               'MED-631': 2,
#               'MED-633': 2,
#               'MED-686': 2,
#               'MED-692': 2,
#               'MED-741': 1,
#               'MED-767': 1,
#               'MED-789': 1,
#               'MED-812': 1,
#               'MED-816': 1,
#               'MED-817': 1,
#               'MED-850': 1,
#               'MED-854': 1,
#               'MED-946': 1,
#               'MED-950': 1,
#               'MED-989': 1,
#               'MED-1000': 1,
#               'MED-1010': 1,
#               'MED-1021': 1,
#               'MED-1062': 1,
#               'MED-1069': 1,
#               'MED-1133': 1,
#               'MED-1168': 1,
#               'MED-1170': 1,
#               'MED-1175': 1,
#               'MED-1177': 1,
#               'MED-1178': 1,
#               'MED-1223': 1,
#               'MED-1226': 1,
#               'MED-1230': 1,
#               'MED-1261': 1,
#               'MED-1332': 1,
#               'MED-1362': 1,
#               'MED-1364': 1,
#               'MED-1383': 1,
#               'MED-1465': 1,
#               'MED-1501': 1,
#               'MED-1504': 1,
#               'MED-1511': 1,
#               'MED-1542': 1,
#               'MED-1554': 1,
#  'The present findings provide an insight into possible mechanisms underlying the antiepileptogenic effects of NE in temporal lobe epilepsy, the hyperexcitability and hyper-responsiveness of the amygdala in certain stress-related affective disorders, and the stress-induced exacerbation of seizure activity in epileptic patients.': defaultdict(int,
#              {}),
#  'D050484': defaultdict(int, {}),
#  'norepinephrine': defaultdict(int,
#              {'MED-363': 2,
#               'MED-580': 2,
#               'MED-1551': 1,
#               'MED-1624': 1,
#               'MED-3148': 1,
#               'MED-3546': 1,
#               'MED-4148': 1,
#               'MED-5365': 1}),
#  'Norepinephrine Plasma Membrane Transport Proteins': defaultdict(int, {}),
#  'Sodium-Dependent Noradrenaline Transporter': defaultdict(int, {}),
#  'Noradrenaline Transporter, Sodium-Dependent': defaultdict(int, {}),
#  'Sodium Dependent Noradrenaline Transporter': defaultdict(int, {}),
#  'Noradrenaline Transporter': defaultdict(int, {}),
#  'Transporter, Noradrenaline': defaultdict(int, {}),
#  'NET Protein, Neuronal': defaultdict(int, {}),
#  'Neuronal NET Protein': defaultdict(int, {}),
#  'Norepinephrine Transporter Protein': defaultdict(int, {}),
#  'Transporter Protein, Norepinephrine': defaultdict(int, {}),
#  'SLC6A2 Protein': defaultdict(int, {}),
#  'Neurotransmitter Transporters, Noradrenaline-Specific': defaultdict(int, {}),
#  'Neurotransmitter Transporters, Noradrenaline Specific': defaultdict(int, {}),
#  'Noradrenaline-Specific Neurotransmitter Transporters': defaultdict(int, {}),
#  'Transporters, Noradrenaline-Specific Neurotransmitter': defaultdict(int, {}),
#  'Norepinephrine Plasma Membrane Transporters': defaultdict(int, {}),
#  'Noradrenaline Plasma Membrane Transport Proteins': defaultdict(int, {}),
#  'Solute Carrier Family 6 Member 2': defaultdict(int, {}),
#  'Norepinephrine Transporter': defaultdict(int, {}),
#  'Transporter, Norepinephrine': defaultdict(int, {}),
#  'Norepinephrine Plasma Membrane Transporter Proteins': defaultdict(int, {}),
#  'benzodiazepines': defaultdict(int, {'MED-627': 2, 'MED-3670': 1}),
#  'In addition, benzodiazepines can be effective in some patients, particularly those with associated anxiety.': defaultdict(int,
#              {}),
#  'D001569': defaultdict(int, {}),
#  'Benzodiazepines': defaultdict(int, {}),
#  'Benzodiazepine Compounds': defaultdict(int, {}),
#  'Benzodiazepine': defaultdict(int, {}),
#  '1-octanol': defaultdict(int, {}),
#  'Several new drugs, including 1-octanol, sodium oxybate, dimethoxymethyl-diphenyl-barbituric acid (T-2000) and carisbamate, are currently under investigation for the treatment of essential tremor.': defaultdict(int,
#              {}),
#  'D020003': defaultdict(int, {}),
#  ...}

# %% [markdown]
# ### Reading the indexes

# %%
with open('index_complete.pkl', 'rb') as file:
    index = pickle.load(file)

# %% [markdown]
# ### Using the indexes

# %%
query = "relations between obesity and cancer"

# Step 1: Tokenize the query
query_tokens = [entity for entity in index.keys() if re.search(r'\b' + re.escape(entity) + r'\b', query)]
if '' in query_tokens:
    query_tokens.remove('')
print(query_tokens)

# Step 2: Find documents containing query tokens
print("Finding documents containing query tokens")
doc_scores = defaultdict(int)
for token in tqdm(query_tokens):
    if token in index:
        for doc, freq in index[token].items():
            doc_scores[doc] += freq

# Step 3: Sort documents by score
sorted_docs = sorted(doc_scores.items(), key=lambda x: x[1], reverse=True)

# Read titles from doc_dump.txt
titles = {}
with open('../../nfcorpus/raw/doc_dump.txt', 'r') as file:
    reader = csv.reader(file, delimiter='\t')
    for row in tqdm(reader, total=5371):
        doc_id = row[0]
        title = row[2]
        titles[doc_id] = title

# Step 4: Print sorted documents
for doc, score in sorted_docs:
    print(f"Document ID: {doc}, Title: {titles[doc]}, Score: {score}")
# Out:
# ['obesity', 'cancer']
# Finding documents containing query tokens
# 100%|██████████| 2/2 [00:00<00:00, 2042.02it/s]
# 100%|██████████| 5371/5371 [00:00<00:00, 77688.37it/s]
# Document ID: MED-63, Title: Leucine signaling in the pathogenesis of type 2 diabetes and obesity, Score: 4
# Document ID: MED-126, Title: Endocrine-Disrupting Chemicals: Associated Disorders and Mechanisms of Action, Score: 4
# Document ID: MED-173, Title: Health and economic burden of the projected obesity trends in the USA and the UK. - PubMed - NCBI, Score: 4
# Document ID: MED-510, Title: An epidemiologic study of thyroid cancer in Hawaii. - PubMed - NCBI, Score: 4
# Document ID: MED-590, Title: Greater Survival After Breast Cancer in Physically Active Women With High Vegetable-Fruit Intake Regardless of Obesity, Score: 4
# Document ID: MED-2, Title: A statistical regression model for the estimation of acrylamide concentrations in French fries for excess lifetime cancer risk assessment. - PubMed - NCBI, Score: 3
# Document ID: MED-48, Title: Agricultural policies, food and public health, Score: 2
# Document ID: MED-58, Title: Macronutrient balance and lifespan, Score: 2
# Document ID: MED-97, Title: Systematic review and meta-analysis of clinical trials of the effects of low carbohydrate diets on cardiovascular risk factors. - PubMed - NCBI, Score: 2
# Document ID: MED-166, Title: The role of exercise in the treatment of obesity. - PubMed - NCBI, Score: 2
# Document ID: MED-167, Title: Physical activity energy expenditure has not declined since the 1980s and matches energy expenditures of wild mammals. - PubMed - NCBI, Score: 2
# Document ID: MED-168, Title: Myths, Presumptions, and Facts about Obesity, Score: 2
# Document ID: MED-169, Title: Energy Balance and Obesity, Score: 2
# Document ID: MED-170, Title: Increased food energy supply is more than sufficient to explain the US epidemic of obesity. - PubMed - NCBI, Score: 2
# Document ID: MED-210, Title: The association between gout and nephrolithiasis: the National Health and Nutrition Examination Survey III, 1988-1994. - PubMed - NCBI, Score: 2
# Document ID: MED-221, Title: Curcumin and obesity. - PubMed - NCBI, Score: 2
# Document ID: MED-224, Title: Epidemiology of OA, Score: 2
# Document ID: MED-225, Title: Pathobiology of obesity and osteoarthritis: integrating biomechanics and inflammation, Score: 2
# Document ID: MED-285, Title: Glucose challenge stimulates reactive oxygen species (ROS) generation by leucocytes. - PubMed - NCBI, Score: 2
# Document ID: MED-313, Title: Obesity and addiction: neurobiological overlaps. - PubMed - NCBI, Score: 2
# Document ID: MED-318, Title: Implications from addiction research towards the understanding and treatment of obesity. - PubMed - NCBI, Score: 2
# Document ID: MED-320, Title: The Neural Correlates of “Food Addiction”, Score: 2
# Document ID: MED-321, Title: Brain PET imaging in obesity and food addiction: current evidence and hypothesis. - PubMed - NCBI, Score: 2
